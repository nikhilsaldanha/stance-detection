# %%
import pandas as pd

import numpy as np

import itertools

from nltk.tokenize import RegexpTokenizer

from nltk.stem.porter import *

import pickle

# %%
stemmer = PorterStemmer()

# %%
df = pd.read_csv("../data/Emergent_NAACL2016/emergent/url-versions-2015-06-14-clean-train-fold-9.csv")

# %%
claims, headlines = np.split(df[["claimHeadline", "articleHeadline"]].values, 2, axis=1)

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
claims_tok = [tokenizer.tokenize(claim.lower()) for claim in claims.flatten()]
headlines_tok = [tokenizer.tokenize(headline.lower()) for headline in headlines.flatten()]

# %%
claims_tok
# Out:
# [['apple', 'will', 'sell', '19', 'million', 'apple', 'watches', 'in', '2015'],
#  ['apple',
#   'will',
#   'sell',
#   '24',
#   'million',
#   'apple',
#   'watches',
#   'in',
#   'the',
#   'first',
#   'nine',
#   'months'],
#  ['apple',
#   'will',
#   'sell',
#   '24',
#   'million',
#   'apple',
#   'watches',
#   'in',
#   'the',
#   'first',
#   'nine',
#   'months'],
#  ['a',
#   '600',
#   'pound',
#   'australian',
#   'woman',
#   'gave',
#   'birth',
#   'to',
#   '40',
#   'pound',
#   'baby'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['a',
#   'wife',
#   'and',
#   'child',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'were',
#   'detained',
#   'in',
#   'lebanon'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['jihadist', 'khalil', 'al', 'britani', 'was', 'killed'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['amazon',
#   'will',
#   'open',
#   'its',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'ny',
#   'this',
#   'year'],
#  ['president',
#   'obama',
#   'ordered',
#   'the',
#   'federal',
#   'reserve',
#   'to',
#   'adopt',
#   'the',
#   'euro'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'an',
#   'amoled',
#   'panel',
#   'from',
#   'lg',
#   'display'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['apple', 'will', 'launch', 'a', '12', 'macbook', 'air', 'in', '2015'],
#  ['the', 'larger', 'apple', 'watch', 'edition', 'will', 'cost', '10', '000'],
#  ['the', 'larger', 'apple', 'watch', 'edition', 'will', 'cost', '10', '000'],
#  ['the', 'larger', 'apple', 'watch', 'edition', 'will', 'cost', '10', '000'],
#  ['the', 'larger', 'apple', 'watch', 'edition', 'will', 'cost', '10', '000'],
#  ['apple',
#   'will',
#   'hold',
#   'a',
#   'special',
#   'medialaunch',
#   'event',
#   'in',
#   'february'],
#  ['apple',
#   'will',
#   'hold',
#   'a',
#   'special',
#   'medialaunch',
#   'event',
#   'in',
#   'february'],
#  ['apple',
#   'will',
#   'hold',
#   'a',
#   'special',
#   'medialaunch',
#   'event',
#   'in',
#   'february'],
#  ['apple',
#   'will',
#   'hold',
#   'a',
#   'special',
#   'medialaunch',
#   'event',
#   'in',
#   'february'],
#  ['apple',
#   'will',
#   'hold',
#   'a',
#   'special',
#   'medialaunch',
#   'event',
#   'in',
#   'february'],
#  ['apple',
#   'will',
#   'hold',
#   'a',
#   'special',
#   'medialaunch',
#   'event',
#   'in',
#   'february'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple', 'is', 'buying', 'path'],
#  ['apple',
#   'will',
#   'reveal',
#   'a',
#   'refreshed',
#   'apple',
#   'tv',
#   'at',
#   'the',
#   'march',
#   '9th',
#   'spring',
#   'forward',
#   'event'],
#  ['apple', 'will', 'sell', '50', 'million', 'apple', 'watches', 'in', '2015'],
#  ['apple', 'will', 'sell', '50', 'million', 'apple', 'watches', 'in', '2015'],
#  ['apple',
#   'watch',
#   'will',
#   'only',
#   'be',
#   'sold',
#   'in',
#   'apple',
#   'stores',
#   'at',
#   'launch'],
#  ['apple',
#   'watch',
#   'will',
#   'only',
#   'be',
#   'sold',
#   'in',
#   'apple',
#   'stores',
#   'at',
#   'launch'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['apple',
#   'watch',
#   'battery',
#   'doesn',
#   't',
#   'last',
#   'more',
#   'than',
#   'one',
#   'day'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'with', 'a', 'diagnostics', 'port'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'with', 'a', 'diagnostics', 'port'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'with', 'a', 'diagnostics', 'port'],
#  ['the',
#   'digital',
#   'crown',
#   'on',
#   'the',
#   'apple',
#   'watch',
#   'will',
#   'come',
#   'in',
#   'different',
#   'colors'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'cost',
#   'between',
#   '4',
#   '000',
#   'and',
#   '5',
#   '000',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'start',
#   'at',
#   '4',
#   '999',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'start',
#   'at',
#   '4',
#   '999',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'start',
#   'at',
#   '4',
#   '999',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'retail',
#   'for',
#   '950',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'retail',
#   'for',
#   '950',
#   'usd'],
#  ['the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'will',
#   'retail',
#   'for',
#   '950',
#   'usd'],
#  ['the',
#   'apple',
#   'watch',
#   'edition',
#   'has',
#   'less',
#   'gold',
#   'than',
#   'typical',
#   '18k',
#   'gold'],
#  ['the',
#   'apple',
#   'watch',
#   'edition',
#   'has',
#   'less',
#   'gold',
#   'than',
#   'typical',
#   '18k',
#   'gold'],
#  ['the',
#   'apple',
#   'watch',
#   'edition',
#   'has',
#   'less',
#   'gold',
#   'than',
#   'typical',
#   '18k',
#   'gold'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'is',
#   'sufficiently',
#   'water',
#   'resistant',
#   'to',
#   'wear',
#   'in',
#   'the',
#   'shower'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'in',
#   'germany',
#   'at',
#   'launch'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'in',
#   'germany',
#   'at',
#   'launch'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'in',
#   'germany',
#   'at',
#   'launch'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'in',
#   'germany',
#   'at',
#   'launch'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'in',
#   'germany',
#   'at',
#   'launch'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'in',
#   'germany',
#   'at',
#   'launch'],
#  ['developers',
#   'have',
#   'limited',
#   'access',
#   'to',
#   'apple',
#   'watch',
#   'sensors',
#   'and',
#   'features',
#   'to',
#   'make',
#   'simpler',
#   'apps',
#   'that',
#   'don',
#   't',
#   'drain',
#   'battery'],
#  ['developers',
#   'have',
#   'limited',
#   'access',
#   'to',
#   'apple',
#   'watch',
#   'sensors',
#   'and',
#   'features',
#   'to',
#   'make',
#   'simpler',
#   'apps',
#   'that',
#   'don',
#   't',
#   'drain',
#   'battery'],
#  ['apple',
#   'watch',
#   'will',
#   'have',
#   '512',
#   'mb',
#   'of',
#   'ram',
#   'and',
#   '4gb',
#   'or',
#   '8gb',
#   'storage',
#   'options'],
#  ['apple',
#   'watch',
#   'will',
#   'have',
#   '512',
#   'mb',
#   'of',
#   'ram',
#   'and',
#   '4gb',
#   'or',
#   '8gb',
#   'storage',
#   'options'],
#  ['apple',
#   'watch',
#   'will',
#   'have',
#   '512',
#   'mb',
#   'of',
#   'ram',
#   'and',
#   '4gb',
#   'or',
#   '8gb',
#   'storage',
#   'options'],
#  ['apple',
#   'watch',
#   'will',
#   'have',
#   '512',
#   'mb',
#   'of',
#   'ram',
#   'and',
#   '4gb',
#   'or',
#   '8gb',
#   'storage',
#   'options'],
#  ['apple',
#   'watch',
#   'will',
#   'have',
#   '512',
#   'mb',
#   'of',
#   'ram',
#   'and',
#   '4gb',
#   'or',
#   '8gb',
#   'storage',
#   'options'],
#  ['the',
#   'apple',
#   'watch',
#   'only',
#   'receives',
#   'notifications',
#   'when',
#   'on',
#   'the',
#   'wrist'],
#  ['apple',
#   'is',
#   'considering',
#   'the',
#   'release',
#   'of',
#   'a',
#   'platinum',
#   'edition',
#   'of',
#   'the',
#   'apple',
#   'watch'],
#  ['apple',
#   'is',
#   'considering',
#   'the',
#   'release',
#   'of',
#   'a',
#   'platinum',
#   'edition',
#   'of',
#   'the',
#   'apple',
#   'watch'],
#  ['apple',
#   'is',
#   'considering',
#   'the',
#   'release',
#   'of',
#   'a',
#   'platinum',
#   'edition',
#   'of',
#   'the',
#   'apple',
#   'watch'],
#  ['apple',
#   'is',
#   'considering',
#   'the',
#   'release',
#   'of',
#   'a',
#   'platinum',
#   'edition',
#   'of',
#   'the',
#   'apple',
#   'watch'],
#  ['apple',
#   'is',
#   'considering',
#   'the',
#   'release',
#   'of',
#   'a',
#   'platinum',
#   'edition',
#   'of',
#   'the',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'a',
#   'feature',
#   'called',
#   'power',
#   'reserve'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'a',
#   'feature',
#   'called',
#   'power',
#   'reserve'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'a',
#   'feature',
#   'called',
#   'power',
#   'reserve'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'a',
#   'feature',
#   'called',
#   'power',
#   'reserve'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'a',
#   'feature',
#   'called',
#   'power',
#   'reserve'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'a',
#   'feature',
#   'called',
#   'power',
#   'reserve'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'include',
#   'a',
#   'feature',
#   'called',
#   'power',
#   'reserve'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the',
#   'apple',
#   'store',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'for', 'valentine', 's', 'day'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'for', 'valentine', 's', 'day'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'for', 'valentine', 's', 'day'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'for', 'valentine', 's', 'day'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'for', 'valentine', 's', 'day'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['the', 'apple', 'watch', 'will', 'ship', 'in', 'march'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'removed',
#   'from',
#   'apple',
#   'watch',
#   'a',
#   'skin',
#   'conductivity',
#   'sensor',
#   'that',
#   'would',
#   'give',
#   'a',
#   'more',
#   'accurate',
#   'heart',
#   'rate'],
#  ['apple',
#   'have',
#   'different',
#   'watch',
#   'bands',
#   'for',
#   'sale',
#   'at',
#   'launch'],
#  ['the', 'apple', 'watch', 'takes', 'about', 'two', 'hours', 'to', 'charge'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['the',
#   'president',
#   'of',
#   'argentina',
#   'became',
#   'the',
#   'adopted',
#   'godmother',
#   'of',
#   'a',
#   'boy',
#   'to',
#   'help',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['teacher', 'had', 'sex', 'with', '16', 'year', 'old'],
#  ['teacher', 'had', 'sex', 'with', '16', 'year', 'old'],
#  ['teacher', 'had', 'sex', 'with', '16', 'year', 'old'],
#  ['teacher', 'had', 'sex', 'with', '16', 'year', 'old'],
#  ['teacher', 'had', 'sex', 'with', '16', 'year', 'old'],
#  ['teacher', 'had', 'sex', 'with', '16', 'year', 'old'],
#  ['teacher', 'had', 'sex', 'with', '16', 'year', 'old'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['anonymous', 'street', 'artist', 'banksy', 'was', 'arrested'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['abdel', 'majed', 'abdel', 'bary', 'beheaded', 'james', 'wright', 'foley'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['the', 'batmobile', 'was', 'stolen'],
#  ['harvard',
#   'professor',
#   'ben',
#   'edelman',
#   'sent',
#   'an',
#   'email',
#   'with',
#   'racist',
#   'overtones',
#   'to',
#   'a',
#   'restaurant',
#   'that',
#   'he',
#   'd',
#   'argued',
#   'with',
#   'over',
#   'food',
#   'pricing'],
#  ['harvard',
#   'professor',
#   'ben',
#   'edelman',
#   'sent',
#   'an',
#   'email',
#   'with',
#   'racist',
#   'overtones',
#   'to',
#   'a',
#   'restaurant',
#   'that',
#   'he',
#   'd',
#   'argued',
#   'with',
#   'over',
#   'food',
#   'pricing'],
#  ['harvard',
#   'professor',
#   'ben',
#   'edelman',
#   'sent',
#   'an',
#   'email',
#   'with',
#   'racist',
#   'overtones',
#   'to',
#   'a',
#   'restaurant',
#   'that',
#   'he',
#   'd',
#   'argued',
#   'with',
#   'over',
#   'food',
#   'pricing'],
#  ['the',
#   'washington',
#   'post',
#   'is',
#   'developing',
#   'a',
#   'new',
#   'app',
#   'that',
#   'will',
#   'be',
#   'pre',
#   'installed',
#   'on',
#   'the',
#   'new',
#   'kindle',
#   'fire'],
#  ['the',
#   'washington',
#   'post',
#   'is',
#   'developing',
#   'a',
#   'new',
#   'app',
#   'that',
#   'will',
#   'be',
#   'pre',
#   'installed',
#   'on',
#   'the',
#   'new',
#   'kindle',
#   'fire'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['a',
#   'man',
#   'was',
#   'saved',
#   'from',
#   'a',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'a',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['big', 'bank', 'hank', 'of', 'the', 'sugarhill', 'gang', 'is', 'dead'],
#  ['a',
#   'video',
#   'of',
#   'bigfoot',
#   'was',
#   'shot',
#   'in',
#   'southwestern',
#   'russia'],
#  ['a',
#   'video',
#   'of',
#   'bigfoot',
#   'was',
#   'shot',
#   'in',
#   'southwestern',
#   'russia'],
#  ['a',
#   'video',
#   'of',
#   'bigfoot',
#   'was',
#   'shot',
#   'in',
#   'southwestern',
#   'russia'],
#  ['a',
#   'video',
#   'of',
#   'bigfoot',
#   'was',
#   'shot',
#   'in',
#   'southwestern',
#   'russia'],
#  ['a',
#   'video',
#   'of',
#   'bigfoot',
#   'was',
#   'shot',
#   'in',
#   'southwestern',
#   'russia'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a', 'bird', 'pooped', 'on', 'vladimir', 'putin', 'during', 'a', 'speech'],
#  ['a',
#   'federal',
#   'judge',
#   'ruled',
#   'that',
#   'black',
#   'women',
#   'do',
#   'not',
#   'have',
#   'independent',
#   'naming',
#   'rights',
#   'for',
#   'their',
#   'children'],
#  ['there',
#   'was',
#   'a',
#   'terrorist',
#   'plot',
#   'to',
#   'target',
#   'black',
#   'friday',
#   'shopppers'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'underage',
#   'bosnian',
#   'girls',
#   'got',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['boston',
#   'marathon',
#   'bombing',
#   'suspect',
#   'dzhokhar',
#   'tsarnaev',
#   'was',
#   'severely',
#   'beaten',
#   'in',
#   'prison'],
#  ['boston',
#   'marathon',
#   'bombing',
#   'suspect',
#   'dzhokhar',
#   'tsarnaev',
#   'was',
#   'severely',
#   'beaten',
#   'in',
#   'prison'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['a',
#   'dna',
#   'test',
#   'proved',
#   'that',
#   'bruno',
#   'mars',
#   'is',
#   'michael',
#   'jackson',
#   's',
#   'son'],
#  ['a',
#   'dna',
#   'test',
#   'proved',
#   'that',
#   'bruno',
#   'mars',
#   'is',
#   'michael',
#   'jackson',
#   's',
#   'son'],
#  ['a',
#   'dna',
#   'test',
#   'proved',
#   'that',
#   'bruno',
#   'mars',
#   'is',
#   'michael',
#   'jackson',
#   's',
#   'son'],
#  ['a',
#   'woman',
#   'broke',
#   'up',
#   'with',
#   'her',
#   'cheating',
#   'boyfriend',
#   'by',
#   'printing',
#   'out',
#   'and',
#   'wrapping',
#   'his',
#   'incriminating',
#   'twitter',
#   'direct',
#   'messages'],
#  ['a',
#   'woman',
#   'broke',
#   'up',
#   'with',
#   'her',
#   'cheating',
#   'boyfriend',
#   'by',
#   'printing',
#   'out',
#   'and',
#   'wrapping',
#   'his',
#   'incriminating',
#   'twitter',
#   'direct',
#   'messages'],
#  ['spurned',
#   'wife',
#   'leaves',
#   'cheating',
#   'husband',
#   'and',
#   'her',
#   'twin',
#   'naked',
#   'in',
#   'busy',
#   'car',
#   'park'],
#  ['spurned',
#   'wife',
#   'leaves',
#   'cheating',
#   'husband',
#   'and',
#   'her',
#   'twin',
#   'naked',
#   'in',
#   'busy',
#   'car',
#   'park'],
#  ['spurned',
#   'wife',
#   'leaves',
#   'cheating',
#   'husband',
#   'and',
#   'her',
#   'twin',
#   'naked',
#   'in',
#   'busy',
#   'car',
#   'park'],
#  ['spurned',
#   'wife',
#   'leaves',
#   'cheating',
#   'husband',
#   'and',
#   'her',
#   'twin',
#   'naked',
#   'in',
#   'busy',
#   'car',
#   'park'],
#  ['the',
#   'chinese',
#   'public',
#   'broadcaster',
#   'published',
#   'an',
#   'article',
#   'on',
#   'tips',
#   'for',
#   'chinese',
#   'choosing',
#   'an',
#   'english',
#   'name'],
#  ['the',
#   'chinese',
#   'public',
#   'broadcaster',
#   'published',
#   'an',
#   'article',
#   'on',
#   'tips',
#   'for',
#   'chinese',
#   'choosing',
#   'an',
#   'english',
#   'name'],
#  ['the',
#   'chinese',
#   'public',
#   'broadcaster',
#   'published',
#   'an',
#   'article',
#   'on',
#   'tips',
#   'for',
#   'chinese',
#   'choosing',
#   'an',
#   'english',
#   'name'],
#  ['the',
#   'chinese',
#   'public',
#   'broadcaster',
#   'published',
#   'an',
#   'article',
#   'on',
#   'tips',
#   'for',
#   'chinese',
#   'choosing',
#   'an',
#   'english',
#   'name'],
#  ['the',
#   'chinese',
#   'public',
#   'broadcaster',
#   'published',
#   'an',
#   'article',
#   'on',
#   'tips',
#   'for',
#   'chinese',
#   'choosing',
#   'an',
#   'english',
#   'name'],
#  ['the',
#   'chinese',
#   'public',
#   'broadcaster',
#   'published',
#   'an',
#   'article',
#   'on',
#   'tips',
#   'for',
#   'chinese',
#   'choosing',
#   'an',
#   'english',
#   'name'],
#  ['the',
#   'chinese',
#   'public',
#   'broadcaster',
#   'published',
#   'an',
#   'article',
#   'on',
#   'tips',
#   'for',
#   'chinese',
#   'choosing',
#   'an',
#   'english',
#   'name'],
#  ['claim',
#   'a',
#   'chinese',
#   'man',
#   'chopped',
#   'off',
#   'his',
#   'own',
#   'penis',
#   'due',
#   'to',
#   'his',
#   'frustration',
#   'with',
#   'not',
#   'finding',
#   'love'],
#  ['claim',
#   'a',
#   'chinese',
#   'man',
#   'chopped',
#   'off',
#   'his',
#   'own',
#   'penis',
#   'due',
#   'to',
#   'his',
#   'frustration',
#   'with',
#   'not',
#   'finding',
#   'love'],
#  ['claim',
#   'a',
#   'chinese',
#   'man',
#   'chopped',
#   'off',
#   'his',
#   'own',
#   'penis',
#   'due',
#   'to',
#   'his',
#   'frustration',
#   'with',
#   'not',
#   'finding',
#   'love'],
#  ['comcast',
#   'is',
#   'telling',
#   'customers',
#   'tor',
#   'is',
#   'illegal',
#   'to',
#   'use'],
#  ['comcast',
#   'is',
#   'telling',
#   'customers',
#   'tor',
#   'is',
#   'illegal',
#   'to',
#   'use'],
#  ['comcast',
#   'is',
#   'telling',
#   'customers',
#   'tor',
#   'is',
#   'illegal',
#   'to',
#   'use'],
#  ['comcast',
#   'is',
#   'telling',
#   'customers',
#   'tor',
#   'is',
#   'illegal',
#   'to',
#   'use'],
#  ['comcast',
#   'is',
#   'telling',
#   'customers',
#   'tor',
#   'is',
#   'illegal',
#   'to',
#   'use'],
#  ['comcast',
#   'is',
#   'telling',
#   'customers',
#   'tor',
#   'is',
#   'illegal',
#   'to',
#   'use'],
#  ['comcast',
#   'is',
#   'telling',
#   'customers',
#   'tor',
#   'is',
#   'illegal',
#   'to',
#   'use'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a', '50', 'foot', 'crab', 'was', 'photographed', 'in', 'the', 'u', 'k'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['a',
#   'child',
#   'soldier',
#   'with',
#   'isis',
#   'was',
#   'killed',
#   'in',
#   'battle',
#   'making',
#   'him',
#   'youngest',
#   'islamic',
#   'state',
#   'fighter',
#   'to',
#   'die'],
#  ['apple',
#   'will',
#   'offer',
#   'custom',
#   'engraving',
#   'on',
#   'the',
#   'apple',
#   'watch'],
#  ['apple',
#   'will',
#   'offer',
#   'custom',
#   'engraving',
#   'on',
#   'the',
#   'apple',
#   'watch'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['nbc',
#   'meteorologist',
#   'mike',
#   'seidel',
#   'was',
#   'caught',
#   'relieving',
#   'himself',
#   'on',
#   'camera'],
#  ['the',
#   'woman',
#   'behind',
#   'the',
#   'hugely',
#   'popular',
#   'dc',
#   'toys',
#   'collector',
#   'disney',
#   'collector',
# ...
#   'human',
#   'organs',
#   'to',
#   'help',
#   'fund',
#   'its',
#   'operations'],
#  ['isis',
#   'is',
#   'harvesting',
#   'and',
#   'selling',
#   'human',
#   'organs',
#   'to',
#   'help',
#   'fund',
#   'its',
#   'operations'],
#  ['isis',
#   'is',
#   'harvesting',
#   'and',
#   'selling',
#   'human',
#   'organs',
#   'to',
#   'help',
#   'fund',
#   'its',
#   'operations'],
#  ['isis',
#   'is',
#   'harvesting',
#   'and',
#   'selling',
#   'human',
#   'organs',
#   'to',
#   'help',
#   'fund',
#   'its',
#   'operations'],
#  ['isis',
#   'is',
#   'harvesting',
#   'and',
#   'selling',
#   'human',
#   'organs',
#   'to',
#   'help',
#   'fund',
#   'its',
#   'operations'],
#  ['isis',
#   'is',
#   'harvesting',
#   'and',
#   'selling',
#   'human',
#   'organs',
#   'to',
#   'help',
#   'fund',
#   'its',
#   'operations'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'was',
#   'killed',
#   'by',
#   'an',
#   'u',
#   's',
#   'airstrike'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis', 'beheaded', 'journalist', 'james', 'wright', 'foley'],
#  ['isis',
#   'gave',
#   'a',
#   'kurdish',
#   'woman',
#   'a',
#   'meal',
#   'and',
#   'told',
#   'her',
#   'she',
#   'd',
#   'eaten',
#   'her',
#   'own',
#   'son'],
#  ['isis',
#   'gave',
#   'a',
#   'kurdish',
#   'woman',
#   'a',
#   'meal',
#   'and',
#   'told',
#   'her',
#   'she',
#   'd',
#   'eaten',
#   'her',
#   'own',
#   'son'],
#  ['isis',
#   'gave',
#   'a',
#   'kurdish',
#   'woman',
#   'a',
#   'meal',
#   'and',
#   'told',
#   'her',
#   'she',
#   'd',
#   'eaten',
#   'her',
#   'own',
#   'son'],
#  ['isis',
#   'gave',
#   'a',
#   'kurdish',
#   'woman',
#   'a',
#   'meal',
#   'and',
#   'told',
#   'her',
#   'she',
#   'd',
#   'eaten',
#   'her',
#   'own',
#   'son'],
#  ['isis',
#   'gave',
#   'a',
#   'kurdish',
#   'woman',
#   'a',
#   'meal',
#   'and',
#   'told',
#   'her',
#   'she',
#   'd',
#   'eaten',
#   'her',
#   'own',
#   'son'],
#  ['isis',
#   'gave',
#   'a',
#   'kurdish',
#   'woman',
#   'a',
#   'meal',
#   'and',
#   'told',
#   'her',
#   'she',
#   'd',
#   'eaten',
#   'her',
#   'own',
#   'son'],
#  ['isis',
#   'gave',
#   'a',
#   'kurdish',
#   'woman',
#   'a',
#   'meal',
#   'and',
#   'told',
#   'her',
#   'she',
#   'd',
#   'eaten',
#   'her',
#   'own',
#   'son'],
#  ['isis', 'is', 'dropping', 'bombs', 'containing', 'live', 'scorpions'],
#  ['isis', 'is', 'dropping', 'bombs', 'containing', 'live', 'scorpions'],
#  ['isis', 'is', 'dropping', 'bombs', 'containing', 'live', 'scorpions'],
#  ['isis', 'is', 'dropping', 'bombs', 'containing', 'live', 'scorpions'],
#  ['isis', 'is', 'dropping', 'bombs', 'containing', 'live', 'scorpions'],
#  ['isis', 'is', 'dropping', 'bombs', 'containing', 'live', 'scorpions'],
#  ['isis', 'is', 'dropping', 'bombs', 'containing', 'live', 'scorpions'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'remains',
#   'of',
#   'james',
#   'foley'],
#  ['an',
#   'isis',
#   'treasurer',
#   'stole',
#   'money',
#   'from',
#   'the',
#   'organization',
#   'and',
#   'fled'],
#  ['an',
#   'isis',
#   'treasurer',
#   'stole',
#   'money',
#   'from',
#   'the',
#   'organization',
#   'and',
#   'fled'],
#  ['an',
#   'isis',
#   'treasurer',
#   'stole',
#   'money',
#   'from',
#   'the',
#   'organization',
#   'and',
#   'fled'],
#  ['an',
#   'isis',
#   'treasurer',
#   'stole',
#   'money',
#   'from',
#   'the',
#   'organization',
#   'and',
#   'fled'],
#  ['israel',
#   'caused',
#   'flooding',
#   'in',
#   'gaza',
#   'by',
#   'opening',
#   'river',
#   'dams'],
#  ['israel',
#   'caused',
#   'flooding',
#   'in',
#   'gaza',
#   'by',
#   'opening',
#   'river',
#   'dams'],
#  ['israel',
#   'caused',
#   'flooding',
#   'in',
#   'gaza',
#   'by',
#   'opening',
#   'river',
#   'dams'],
#  ['israel',
#   'caused',
#   'flooding',
#   'in',
#   'gaza',
#   'by',
#   'opening',
#   'river',
#   'dams'],
#  ['israel',
#   'caused',
#   'flooding',
#   'in',
#   'gaza',
#   'by',
#   'opening',
#   'river',
#   'dams'],
#  ['israel',
#   'caused',
#   'flooding',
#   'in',
#   'gaza',
#   'by',
#   'opening',
#   'river',
#   'dams'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['italian', 'fishermen', 'caught', 'a', '280', 'pound', 'catfish'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['an',
#   'nun',
#   'in',
#   'an',
#   'italian',
#   'convent',
#   'gave',
#   'birth',
#   'to',
#   'a',
#   'child'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'broke', 'both', 'of', 'his', 'ankles'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'ill',
#   'because',
#   'he',
#   'eats',
#   'too',
#   'much',
#   'cheese'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'drinking',
#   'cobra',
#   'wine',
#   'to',
#   'help',
#   'restore',
#   'his',
#   'virility'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'drinking',
#   'cobra',
#   'wine',
#   'to',
#   'help',
#   'restore',
#   'his',
#   'virility'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'drinking',
#   'cobra',
#   'wine',
#   'to',
#   'help',
#   'restore',
#   'his',
#   'virility'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'drinking',
#   'cobra',
#   'wine',
#   'to',
#   'help',
#   'restore',
#   'his',
#   'virility'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'drinking',
#   'cobra',
#   'wine',
#   'to',
#   'help',
#   'restore',
#   'his',
#   'virility'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['jose', 'canseco', 'was', 'shot'],
#  ['judd', 'nelson', 'is', 'dead'],
#  ['judd', 'nelson', 'is', 'dead'],
#  ['judd', 'nelson', 'is', 'dead'],
#  ['judd', 'nelson', 'is', 'dead'],
#  ['judd', 'nelson', 'is', 'dead'],
#  ['judd', 'nelson', 'is', 'dead'],
#  ['judd', 'nelson', 'is', 'dead'],
#  ['kanye',
#   'west',
#   'has',
#   'been',
#   'banned',
#   'from',
#   'future',
#   'awards',
#   'shows'],
#  ['kanye',
#   'west',
#   'has',
#   'been',
#   'banned',
#   'from',
#   'future',
#   'awards',
#   'shows'],
#  ['kanye',
#   'west',
#   'has',
#   'been',
#   'banned',
#   'from',
#   'future',
#   'awards',
#   'shows'],
#  ['kei',
#   'nishikori',
#   'is',
#   'the',
#   'world',
#   's',
#   'highest',
#   'paid',
#   'tennis',
#   'player'],
#  ['kei',
#   'nishikori',
#   'is',
#   'the',
#   'world',
#   's',
#   'highest',
#   'paid',
#   'tennis',
#   'player'],
#  ['kei',
#   'nishikori',
#   'is',
#   'the',
#   'world',
#   's',
#   'highest',
#   'paid',
#   'tennis',
#   'player'],
#  ...]

# %%
headlines_tok
# Out:
# [['bmo',
#   'forecasts',
#   '19m',
#   'apple',
#   'watch',
#   'sales',
#   'in',
#   '2015',
#   'with',
#   'more',
#   'than',
#   'half',
#   'selling',
#   'in',
#   'holiday',
#   'season'],
#  ['ubs',
#   'survey',
#   'finds',
#   '10',
#   'of',
#   'consumers',
#   'want',
#   'a',
#   'smartwatch',
#   'expects',
#   '24m',
#   'apple',
#   'watch',
#   'sales',
#   'in',
#   'fiscal',
#   '2015'],
#  ['10',
#   'of',
#   'consumers',
#   'very',
#   'likely',
#   'to',
#   'buy',
#   'a',
#   'smartwatch',
#   'in',
#   '2015',
#   'suggesting',
#   '24m',
#   'apple',
#   'watches'],
#  ['australia',
#   '600',
#   'pound',
#   'woman',
#   'gives',
#   'birth',
#   'to',
#   '40',
#   'pound',
#   'baby'],
#  ['iraq',
#   'says',
#   'arrested',
#   'woman',
#   'is',
#   'not',
#   'the',
#   'wife',
#   'of',
#   'isis',
#   'leader',
#   'al',
#   'baghdadi'],
#  ['dna',
#   'tests',
#   'confirm',
#   'lebanon',
#   'is',
#   'holding',
#   'isis',
#   'leader',
#   's',
#   'child'],
#  ['dna',
#   'test',
#   'confirms',
#   'child',
#   'is',
#   'is',
#   'head',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   's',
#   'daughter'],
#  ['lebanon', 'detains', 'wife', 'and', 'son', 'of', 'al', 'baghdadi'],
#  ['lebanon', 'confirms', 'holding', 'isis', 'chief', 's', 'kin'],
#  ['lebanon', 'holding', 'is', 'leader', 's', 'daughter', 'and', 'ex', 'wife'],
#  ['confusion', 'surrounds', 'capture', 'of', 'isis', 'leader', 's', 'wife'],
#  ['mystery',
#   'surrounds',
#   'arrest',
#   'of',
#   'woman',
#   'who',
#   'may',
#   'be',
#   'isis',
#   'leader',
#   's',
#   'wife'],
#  ['iraq',
#   'claims',
#   'isis',
#   'leader',
#   'al',
#   'baghdadi',
#   's',
#   'wife',
#   'has',
#   'not',
#   'been',
#   'arrested',
#   'despite',
#   'lebanon',
#   'insisting',
#   'woman',
#   'detained',
#   'at',
#   'border',
#   'told',
#   'them',
#   'she',
#   'was',
#   'islamist',
#   'extremist',
#   's',
#   'spouse'],
#  ['dna',
#   'tests',
#   'prove',
#   'lebanon',
#   'is',
#   'holding',
#   'isis',
#   'chief',
#   'al',
#   'baghdadi',
#   's',
#   'ex',
#   'wife',
#   'and',
#   'daughter',
#   'after',
#   'they',
#   'were',
#   'caught',
#   'with',
#   'fake',
#   'passports'],
#  ['wife',
#   'of',
#   'isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'detained',
#   'in',
#   'lebanon'],
#  ['iraq',
#   'denies',
#   'lebanon',
#   'captured',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   's',
#   'wife',
#   'and',
#   'child'],
#  ['isis',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   's',
#   'wife',
#   'and',
#   'son',
#   'detained',
#   'in',
#   'lebanon'],
#  ['wife',
#   'and',
#   'son',
#   'of',
#   'islamic',
#   'state',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'detained',
#   'in',
#   'lebanon'],
#  ['wife',
#   'and',
#   'son',
#   'of',
#   'isil',
#   'leader',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'detained',
#   'at',
#   'lebanon',
#   'border'],
#  ['the', 'arrest', 'of', 'the', 'isis', 'leader', 's', 'wife', 'and', 'son'],
#  ['islamic',
#   'state',
#   'leader',
#   's',
#   'family',
#   'detained',
#   'by',
#   'lebanon',
#   'officials',
#   'say'],
#  ['woman',
#   'detained',
#   'in',
#   'lebanon',
#   'is',
#   'not',
#   'al',
#   'baghdadi',
#   's',
#   'wife',
#   'iraq',
#   'says'],
#  ['wife',
#   'and',
#   'child',
#   'of',
#   'islamic',
#   'state',
#   'leader',
#   'baghdadi',
#   'held',
#   'in',
#   'lebanon'],
#  ['wife',
#   'child',
#   'of',
#   'islamic',
#   'state',
#   'head',
#   'abu',
#   'bakr',
#   'al',
#   'baghdadi',
#   'held',
#   'in',
#   'lebanon',
#   'officials',
#   'say'],
#  ['british', 'jihadi', 'killed', 'in', 'us', 'airstrike', 'reports'],
#  ['teenage',
#   'british',
#   'jihadi',
#   'killed',
#   'in',
#   'us',
#   'airstrikes',
#   '19',
#   'year',
#   'old',
#   'from',
#   'brighton',
#   'died',
#   'in',
#   'us',
#   'led',
#   'bombing'],
#  ['brit',
#   'teenage',
#   'jihadi',
#   'killed',
#   'in',
#   'syrian',
#   'airstrike',
#   'as',
#   'britain',
#   'set',
#   'to',
#   'enter',
#   'war'],
#  ['jihadist', 'brit', 'teen', 'killed', 'in', 'us', 'air', 'strikes'],
#  ['british',
#   'teenager',
#   'ibrahim',
#   'kamara',
#   'killed',
#   'in',
#   'us',
#   'airstrikes',
#   'in',
#   'syria'],
#  ['syria',
#   'teenage',
#   'british',
#   'jihadi',
#   'from',
#   'brighton',
#   'killed',
#   'in',
#   'us',
#   'airstrikes'],
#  ['brighton',
#   'teenage',
#   'jihadi',
#   'known',
#   'as',
#   'khalil',
#   'al',
#   'britani',
#   'killed',
#   'in',
#   'syria',
#   'drone',
#   'strike'],
#  ['british',
#   'teenage',
#   'jihadist',
#   'killed',
#   'during',
#   'us',
#   'air',
#   'strikes',
#   'on',
#   'syria'],
#  ['brighton',
#   'jihadi',
#   'among',
#   'five',
#   'killed',
#   'in',
#   'syria',
#   'drone',
#   'strike'],
#  ['brighton',
#   'teenager',
#   'killed',
#   'in',
#   'us',
#   'air',
#   'strikes',
#   'in',
#   'syria'],
#  ['british',
#   'teenage',
#   'jihadi',
#   'believed',
#   'to',
#   'have',
#   'been',
#   'killed',
#   'in',
#   'syria'],
#  ['amazon',
#   'is',
#   'opening',
#   'a',
#   'brick',
#   'and',
#   'mortar',
#   'store',
#   'in',
#   'manhattan'],
#  ['amazon', 'to', 'open', 'first', 'brick', 'and', 'mortar', 'site'],
#  ['amazon', 'is', 'opening', 'its', 'first', 'physical', 'store'],
#  ['amazon', 'is', 'going', 'to', 'open', 'a', 'physical', 'store'],
#  ['amazon',
#   'com',
#   'to',
#   'open',
#   'first',
#   'physical',
#   'store',
#   'in',
#   'manhattan',
#   'dj'],
#  ['amazon',
#   's',
#   'first',
#   'brick',
#   'and',
#   'mortar',
#   'store',
#   'said',
#   'to',
#   'open',
#   'in',
#   'manhattan'],
#  ['amazon',
#   'is',
#   'about',
#   'to',
#   'open',
#   'its',
#   'first',
#   'ever',
#   'physical',
#   'store',
#   'in',
#   'new',
#   'york',
#   'city'],
#  ['amazon',
#   'to',
#   'launch',
#   'first',
#   'brick',
#   'and',
#   'mortar',
#   'store',
#   'report',
#   'says'],
#  ['obama', 'orders', 'fed', 'to', 'adopt', 'euro', 'currency'],
#  ['apple',
#   'watch',
#   'to',
#   'come',
#   'with',
#   'amoled',
#   'panels',
#   'from',
#   'lg',
#   'display'],
#  ['apple',
#   's',
#   'next',
#   'major',
#   'mac',
#   'revealed',
#   'the',
#   'radically',
#   'new',
#   '12',
#   'inch',
#   'macbook',
#   'air'],
#  ['huge',
#   'new',
#   'leak',
#   'reveals',
#   'apple',
#   's',
#   'radically',
#   'redesigned',
#   '12',
#   'inch',
#   'macbook',
#   'air'],
#  ['a',
#   'radically',
#   'redesigned',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   'is',
#   'coming'],
#  ['the',
#   'next',
#   'macbook',
#   'air',
#   'will',
#   'be',
#   'a',
#   '12',
#   'inch',
#   'beauty',
#   'with',
#   'an',
#   'edge',
#   'to',
#   'edge',
#   'keyboard'],
#  ['apple',
#   's',
#   'new',
#   'macbook',
#   'will',
#   'be',
#   'a',
#   'thinner',
#   'cleaner',
#   'faster',
#   '12',
#   'inch',
#   'macbook',
#   'air'],
#  ['apple',
#   'may',
#   'launch',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   'with',
#   'retina',
#   'display'],
#  ['apple',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   'details',
#   'emerge',
#   'device',
#   'could',
#   'be',
#   'thinner',
#   'lighter',
#   'than',
#   'current',
#   'model'],
#  ['apple',
#   's',
#   '12',
#   'inch',
#   'retina',
#   'macbook',
#   'air',
#   'shown',
#   'in',
#   'artist',
#   's',
#   'renditions'],
#  ['apple',
#   's',
#   'next',
#   'macbook',
#   'could',
#   'be',
#   'a',
#   '12',
#   'inch',
#   'macbook',
#   'air'],
#  ['12in',
#   'retina',
#   'macbook',
#   'air',
#   'release',
#   'date',
#   'rumours',
#   'all',
#   'new',
#   '12in',
#   'macbook',
#   'air',
#   'design',
#   'for',
#   '2015',
#   'launching',
#   'at',
#   'wwdc'],
#  ['new',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   'slims',
#   'down',
#   'has',
#   'single',
#   'usb',
#   'port'],
#  ['apple',
#   'reportedly',
#   'preparing',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   'thinner',
#   'and',
#   'lighter',
#   'than',
#   'existing',
#   'models'],
#  ['apple', 'working', 'on', '12', 'inch', 'macbook', 'air'],
#  ['is',
#   'apple',
#   'about',
#   'to',
#   'launch',
#   'a',
#   'totally',
#   'redesigned',
#   '12',
#   'inch',
#   'macbook',
#   'air'],
#  ['why',
#   'the',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'must',
#   'cost',
#   '10',
#   '000'],
#  ['why',
#   'the',
#   'most',
#   'expensive',
#   'apple',
#   'watch',
#   'will',
#   'probably',
#   'cost',
#   'around',
#   '10',
#   '000'],
#  ['gold',
#   'apple',
#   'watch',
#   'edition',
#   'price',
#   'speculators',
#   'say',
#   'at',
#   'least',
#   '10',
#   '000'],
#  ['would', 'you', 'pay', '10', '000', 'for', 'the', 'apple', 'watch'],
#  ['don',
#   't',
#   'cancel',
#   'your',
#   'ski',
#   'plans',
#   'apple',
#   's',
#   'not',
#   'having',
#   'an',
#   'event',
#   'in',
#   'feb'],
#  ['rumor',
#   'apple',
#   'to',
#   'hold',
#   'event',
#   'this',
#   'month',
#   'to',
#   'unveil',
#   'retina',
#   'macbook',
#   'air',
#   'finalize',
#   'apple',
#   'watch',
#   'specs'],
#  ['apple',
#   's',
#   'next',
#   'big',
#   'event',
#   'reportedly',
#   'set',
#   'for',
#   'late',
#   'february'],
#  ['apple',
#   'could',
#   'make',
#   'a',
#   'special',
#   'event',
#   'in',
#   'late',
#   'february',
#   'update'],
#  ['apple',
#   'media',
#   'event',
#   'rumored',
#   'for',
#   'late',
#   'february',
#   'apple',
#   'watch',
#   'and',
#   '12',
#   'macbook',
#   'air',
#   'likely',
#   'topics',
#   'updated'],
#  ['apple',
#   'may',
#   'or',
#   'may',
#   'not',
#   'hold',
#   'an',
#   'event',
#   'on',
#   'the',
#   '24th',
#   'of',
#   'february',
#   'rumor'],
#  ['rumor',
#   'apple',
#   'in',
#   'late',
#   'stage',
#   'talks',
#   'to',
#   'buy',
#   'path',
#   'social',
#   'platform'],
#  ['apple', 'may', 'buy', 'social', 'network', 'path'],
#  ['wednesday',
#   'apple',
#   'rumors',
#   'apple',
#   'may',
#   'be',
#   'ready',
#   'to',
#   'buy',
#   'path'],
#  ['source',
#   'apple',
#   'set',
#   'to',
#   'acquire',
#   'path',
#   'in',
#   'an',
#   'attempt',
#   'to',
#   'bolster',
#   'ios',
#   'social',
#   'cred'],
#  ['morin',
#   'goes',
#   'back',
#   'on',
#   'transparency',
#   'pledge',
#   'refuses',
#   'to',
#   'confirm',
#   'or',
#   'deny',
#   'report',
#   'that',
#   'apple',
#   'is',
#   'buying',
#   'path'],
#  ['four',
#   'reasons',
#   'not',
#   'to',
#   'give',
#   'up',
#   'hope',
#   'if',
#   'apple',
#   'buys',
#   'path'],
#  ['apple',
#   'reported',
#   'to',
#   'be',
#   'near',
#   'buying',
#   'path',
#   'social',
#   'network'],
#  ['apple', 'in', 'late', 'stages', 'to', 'acquire', 'path', 'report', 'says'],
#  ['here',
#   's',
#   'what',
#   'you',
#   'can',
#   'do',
#   'on',
#   'path',
#   'the',
#   'social',
#   'network',
#   'that',
#   'apple',
#   'may',
#   'be',
#   'about',
#   'to',
#   'acquire'],
#  ['apple',
#   'will',
#   'acquire',
#   'path',
#   'the',
#   'struggling',
#   'social',
#   'network'],
#  ['apple',
#   'could',
#   'be',
#   'eyeing',
#   'purchase',
#   'of',
#   'social',
#   'networking',
#   'app',
#   'path'],
#  ['everything',
#   'you',
#   'need',
#   'to',
#   'know',
#   'about',
#   'path',
#   'the',
#   'struggling',
#   'social',
#   'network',
#   'in',
#   'apple',
#   's',
#   'sights'],
#  ['apple',
#   'reportedly',
#   'close',
#   'to',
#   'acquiring',
#   'path',
#   'looking',
#   'to',
#   'integrate',
#   'service',
#   'into',
#   'messages'],
#  ['apple',
#   'may',
#   'buy',
#   'path',
#   'that',
#   'social',
#   'app',
#   'you',
#   'don',
#   't',
#   'use'],
#  ['apple',
#   'plans',
#   'relaunched',
#   'beats',
#   'streaming',
#   'music',
#   'service',
#   'for',
#   'wwdc',
#   'skipping',
#   'march',
#   'event',
#   'apple',
#   'tv',
#   'still',
#   'coming'],
#  ['samsung',
#   'reportedly',
#   'missing',
#   'out',
#   'on',
#   'huge',
#   '50',
#   'million',
#   'apple',
#   'watch',
#   'display',
#   'deal'],
#  ['apple',
#   'hopes',
#   'to',
#   'sell',
#   'over',
#   '50',
#   'million',
#   'watches',
#   'in',
#   '2015'],
#  ['apple',
#   'watch',
#   'release',
#   'well',
#   'initially',
#   'only',
#   'in',
#   'apple',
#   'stores'],
#  ['if',
#   'you',
#   'want',
#   'an',
#   'apple',
#   'watch',
#   'you',
#   'll',
#   'probably',
#   'be',
#   'trekking',
#   'to',
#   'an',
#   'apple',
#   'store'],
#  ['apple',
#   'reportedly',
#   'not',
#   'happy',
#   'with',
#   'one',
#   'day',
#   'watch',
#   'battery',
#   'life',
#   'expects',
#   'improvements',
#   'by',
#   '2015',
#   'launch'],
#  ['apple',
#   'watch',
#   'users',
#   'will',
#   'need',
#   'to',
#   'recharge',
#   'nightly',
#   'company',
#   'still',
#   'working',
#   'to',
#   'improve',
#   'uptime',
#   'before',
#   'launch'],
#  ['it',
#   's',
#   'confirmed',
#   'you',
#   'll',
#   'have',
#   'to',
#   'recharge',
#   'your',
#   'apple',
#   'watch',
#   'every',
#   'night'],
#  ['apple', 'watch', 'will', 'need', 'charging', 'every', 'day'],
#  ['codered', 'apple', 'watch', 'battery', 'life', 'charge', 'nightly'],
#  ['apple',
#   'isn',
#   't',
#   'happy',
#   'with',
#   'the',
#   'battery',
#   'life',
#   'of',
#   'its',
#   'new',
#   'smartwatch'],
#  ['apple', 'watch', 'battery', 'will', 'require', 'nightly', 'charging'],
#  ['apple',
#   'watch',
#   'battery',
#   'life',
#   'currently',
#   'about',
#   'a',
#   'day',
#   'but',
#   'may',
#   'improve',
#   'for',
#   '2015',
#   'launch'],
#  ['apple',
#   'watch',
#   'has',
#   'a',
#   'lightning',
#   'port',
#   'for',
#   'development',
#   'but',
#   'won',
#   't',
#   'when',
#   'it',
#   'ships'],
#  ['apple',
#   'watch',
#   'reportedly',
#   'features',
#   'unannounced',
#   'diagnostics',
#   'port',
#   'under',
#   'strap',
#   'connector'],
#  ['hidden',
#   'diagnostic',
#   'port',
#   'on',
#   'apple',
#   'watch',
#   'could',
#   'allow',
#   'for',
#   'smart',
#   'band',
#   'accessories',
#   'updated'],
#  ['apple', 'watch', 'digital', 'crown', 'could', 'it', 'color', 'adjusted'],
#  ['report',
#   'claims',
#   'steel',
#   'apple',
#   'watch',
#   'to',
#   'start',
#   'at',
#   '500',
#   'gold',
#   'model',
#   'between',
#   '4',
#   '5k'],
#  ['rumor',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'priced',
#   'up',
#   'to',
#   '5',
#   '000',
#   'steel',
#   'version',
#   'at',
#   '500',
#   'will',
#   'debut',
#   'on',
#   'feb',
#   '14'],
#  ['rumor',
#   'stainless',
#   'steel',
#   'apple',
#   'watch',
#   'will',
#   'cost',
#   '500',
#   'gold',
#   '4',
#   '000'],
#  ['apple',
#   'watch',
#   'to',
#   'start',
#   'at',
#   '500',
#   'in',
#   'stainless',
#   'steel',
#   'thousands',
#   'for',
#   'gold',
#   'model'],
#  ['apple',
#   'watch',
#   'stainless',
#   'steel',
#   'variant',
#   'reportedly',
#   'priced',
#   'at',
#   '500',
#   '4',
#   '000',
#   'for',
#   'the',
#   'gold',
#   'variant'],
#  ['stainless',
#   'steel',
#   'apple',
#   'watch',
#   'could',
#   'cost',
#   'just',
#   '499',
#   'but',
#   'gold',
#   'will',
#   'be',
#   '10',
#   'times',
#   'as',
#   'pricey'],
#  ['info', 'igen', '500', 'for', 'apple', 'watch', 'february', '14'],
#  ['apple',
#   'watch',
#   'pricing',
#   'to',
#   'reportedly',
#   'start',
#   'at',
#   '500',
#   'for',
#   'stainless',
#   'steel',
#   '4',
#   '000',
#   'for',
#   'gold'],
#  ['stainless',
#   'steel',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'priced',
#   '500',
#   'gold',
#   'at',
#   '5',
#   '000'],
#  ['apple',
#   'watch',
#   'pricing',
#   'will',
#   'you',
#   'spend',
#   '5000',
#   'for',
#   'gold',
#   'edition',
#   '500',
#   'for',
#   'stainless',
#   'steel'],
#  ['piper',
#   'jaffray',
#   'pegs',
#   'stainless',
#   'steel',
#   'apple',
#   'watch',
#   'price',
#   'at',
#   '499',
#   'edition',
#   'at',
#   '4',
#   '999'],
#  ['high', 'end', 'apple', 'watch', 'to', 'start', 'at', '5', '000', 'analyst'],
#  ['gene',
#   'munster',
#   'predicts',
#   '499',
#   'steel',
#   'apple',
#   'watch',
#   '4',
#   '999',
#   'for',
#   '18k',
#   'gold',
#   'edition'],
#  ['apple',
#   'citi',
#   'sees',
#   '550',
#   'and',
#   '950',
#   'apple',
#   'watches',
#   'accessory',
#   'plethora'],
#  ['citi',
#   'sees',
#   'apple',
#   'watch',
#   'price',
#   'points',
#   'of',
#   '550',
#   'and',
#   '950',
#   'myriad',
#   'accessories'],
#  ['analyst', 'apple', 'watch', 'edition', 'to', 'cost', '950'],
#  ['brilliant',
#   'patent',
#   'details',
#   'how',
#   'apple',
#   'may',
#   'be',
#   'saving',
#   'money',
#   'on',
#   'the',
#   '18k',
#   'gold',
#   'apple',
#   'watch'],
#  ['apple',
#   'watch',
#   'edition',
#   'will',
#   'save',
#   'on',
#   'gold',
#   'with',
#   'patented',
#   'alloy',
#   'could',
#   'start',
#   'at',
#   '2',
#   '999'],
#  ['apple', 'watch', 'edition', 'contains', 'new', 'apple', 'gold'],
#  ['tim',
#   'cook',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'showerproof',
#   'apple',
#   'pay',
#   'goal',
#   'for',
#   'europe',
#   'is',
#   'end',
#   'of',
#   'the',
#   'year'],
#  ['apple',
#   'watch',
#   'to',
#   'be',
#   'shower',
#   'proof',
#   'have',
#   '100',
#   '000',
#   'apps',
#   'at',
#   'launch',
#   'reports'],
#  ['yes',
#   'you',
#   'can',
#   'wear',
#   'your',
#   'apple',
#   'watch',
#   'in',
#   'the',
#   'shower'],
#  ['that',
#   's',
#   'one',
#   'way',
#   'to',
#   'clean',
#   'it',
#   'apple',
#   'watch',
#   'will',
#   'reportedly',
#   'survive',
#   'a',
#   'trip',
#   'through',
#   'the',
#   'shower'],
#  ['tim', 'cook', 'i', 'wear', 'my', 'apple', 'watch', 'in', 'the', 'shower'],
#  ['tim',
#   'cook',
#   'reportedly',
#   'showers',
#   'with',
#   'apple',
#   'watch',
#   'suggesting',
#   'it',
#   's',
#   'waterproof'],
#  ['cook',
#   'said',
#   'to',
#   'confirm',
#   'apple',
#   'watch',
#   'is',
#   'showerproof',
#   'lasts',
#   'a',
#   'day'],
#  ['tim',
#   'cook',
#   'reportedly',
#   'reveals',
#   'apple',
#   'watch',
#   'waterproofing',
#   'has',
#   'improved'],
#  ['tim',
#   'cook',
#   'says',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'outside',
#   'u',
#   's',
#   'in',
#   'april'],
#  ['apple', 'watch', 'won', 't', 'be', 'a', 'u', 's', 'only', 'launch'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'launch',
#   'outside',
#   'the',
#   'us',
#   'in',
#   'april',
#   'too'],
#  ['the',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'available',
#   'outside',
#   'the',
#   'us',
#   'when',
#   'it',
#   'launches',
#   'next',
#   'month'],
#  ['tim',
#   'cook',
#   'teases',
#   'apple',
#   'watch',
#   'launch',
#   'apps',
#   'and',
#   'its',
#   'debut',
#   'in',
#   'germany'],
#  ['apple',
#   'watch',
#   'may',
#   'be',
#   'available',
#   'outside',
#   'us',
#   'shortly',
#   'after',
#   'launch'],
#  ['apple',
#   'watch',
#   'developers',
#   'told',
#   'to',
#   'limit',
#   'features',
#   'to',
#   'save',
#   'battery',
#   'life'],
#  ['apple',
#   'is',
#   'limiting',
#   'features',
#   'on',
#   'the',
#   'apple',
#   'watch',
#   'to',
#   'save',
#   'battery',
#   'life',
#   'according',
#   'to',
#   'developers'],
#  ['rumor',
#   'apple',
#   'watch',
#   'to',
#   'feature',
#   '512mb',
#   'of',
#   'ram',
#   '4gb',
#   'of',
#   'storage'],
#  ['apple',
#   'watch',
#   'will',
#   'reportedly',
#   'have',
#   'pretty',
#   'unimpressive',
#   'specs'],
#  ['apple',
#   'watch',
#   'specs',
#   'tipped',
#   'said',
#   'to',
#   'feature',
#   '512mb',
#   'ram',
#   '4gb',
#   'of',
#   'storage'],
#  ['apple', 's', 'watch', 'will', 'come', 'in', '2', 'storage', 'sizes'],
#  ['spec',
#   'leak',
#   'suggests',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'on',
#   'par',
#   'with',
#   'android',
#   'wear',
#   'rivals'],
#  ['apple',
#   'watch',
#   'takes',
#   'two',
#   'hours',
#   'to',
#   'charge',
#   'only',
#   'delivers',
#   'notifications',
#   'while',
#   'on',
#   'the',
#   'wrist'],
#  ['apple',
#   'saving',
#   'money',
#   'on',
#   'the',
#   'gold',
#   'in',
#   'apple',
#   'watch',
#   'edition',
#   'could',
#   'be',
#   'planning',
#   'a',
#   'platinum',
#   'model',
#   'for',
#   'future',
#   'designs'],
#  ['future',
#   'apple',
#   'watches',
#   'could',
#   'include',
#   'platinum',
#   'models',
#   'report'],
#  ['forget',
#   '18',
#   'karat',
#   'gold',
#   'next',
#   'generation',
#   'apple',
#   'watch',
#   'edition',
#   'could',
#   'use',
#   'platinum',
#   'report'],
#  ['apple',
#   'to',
#   'take',
#   'reservations',
#   'for',
#   'trying',
#   'on',
#   'apple',
#   'watch',
#   'considered',
#   'platinum',
#   'model'],
#  ['the', 'next', 'apple', 'watch', 'could', 'be', 'platinum'],
#  ['nyt',
#   'apple',
#   'watch',
#   'includes',
#   'power',
#   'reserve',
#   'mode',
#   'shows',
#   'only',
#   'the',
#   'time',
#   'but',
#   'conserves',
#   'battery',
#   'life'],
#  ['apple',
#   'watch',
#   'to',
#   'reportedly',
#   'offer',
#   'power',
#   'reserve',
#   'to',
#   'help',
#   'extend',
#   'battery',
#   'life'],
#  ['apple',
#   'watch',
#   'power',
#   'reserve',
#   'feature',
#   'will',
#   'save',
#   'battery',
#   'life',
#   'report',
#   'says'],
#  ['the',
#   'apple',
#   'watch',
#   'has',
#   'a',
#   'low',
#   'power',
#   'mode',
#   'that',
#   'only',
#   'tells',
#   'the',
#   'time'],
#  ['apple',
#   'watch',
#   'to',
#   'feature',
#   'time',
#   'only',
#   'power',
#   'reserve',
#   'mode',
#   'prototypes',
#   'disguised',
#   'as',
#   'samsung',
#   'watches'],
#  ['apple',
#   'watch',
#   's',
#   'power',
#   'reserve',
#   'feature',
#   'combats',
#   'short',
#   'battery',
#   'life'],
#  ['apple',
#   'watch',
#   'reportedly',
#   'has',
#   'low',
#   'energy',
#   'power',
#   'reserve',
#   'mode'],
#  ['apple',
#   'is',
#   'bringing',
#   'special',
#   'safes',
#   'to',
#   'its',
#   'stores',
#   'just',
#   'to',
#   'house',
#   'the',
#   '18k',
#   'gold',
#   'apple',
#   'watch'],
#  ['apple',
#   'to',
#   'keep',
#   'gold',
#   'watch',
#   'editions',
#   'in',
#   'special',
#   'in',
#   'store',
#   'safes'],
#  ['apple',
#   'stores',
#   'will',
#   'have',
#   'custom',
#   'designed',
#   'safes',
#   'to',
#   'store',
#   'the',
#   'gold',
#   'apple',
#   'watch',
#   'in'],
#  ['apple',
#   'stores',
#   'to',
#   'install',
#   'safes',
#   'to',
#   'secure',
#   'gold',
#   'apple',
#   'watches'],
#  ['apple',
#   'stores',
#   'are',
#   'reportedly',
#   'installing',
#   'custom',
#   'safes',
#   'to',
#   'house',
#   'apple',
#   'watches'],
#  ['apple',
#   'installing',
#   'safes',
#   'in',
#   'store',
#   'to',
#   'protect',
#   'gold',
#   'watch',
#   'edition'],
#  ['apple',
#   'watch',
#   'edition',
#   'special',
#   'safes',
#   'to',
#   'be',
#   'installed',
#   'in',
#   'apple',
#   'stores',
#   'to',
#   'house',
#   'luxury',
#   'smart',
#   'watch'],
#  ['apple',
#   'stores',
#   'to',
#   'keep',
#   'gold',
#   'edition',
#   'apple',
#   'watch',
#   'in',
#   'custom',
#   'safes'],
#  ['18',
#   'karat',
#   'gold',
#   'apple',
#   'watch',
#   'edition',
#   'to',
#   'be',
#   'locked',
#   'in',
#   'safes',
#   'at',
#   'apple',
#   'stores'],
#  ['gold',
#   'apple',
#   'watches',
#   'to',
#   'be',
#   'stored',
#   'in',
#   'safes',
#   'in',
#   'apple',
#   'stores'],
#  ['apple',
#   'watch',
#   'price',
#   'release',
#   'date',
#   'news',
#   'special',
#   'safes',
#   'in',
#   'apple',
#   'stores',
#   'for',
#   'gold',
#   'models',
#   'april',
#   'launch',
#   'confirmed'],
#  ['apple', 'watches', 'to', 'be', 'kept', 'in', 'safes'],
#  ['gold',
#   'apple',
#   'watch',
#   'will',
#   'be',
#   'stored',
#   'in',
#   'special',
#   'safes',
#   'at',
#   'apple',
#   'stores'],
#  ['will',
#   'apple',
#   'hit',
#   'a',
#   'valentine',
#   's',
#   'day',
#   '2015',
#   'target',
#   'for',
#   'the',
#   'apple',
#   'watch',
#   's',
#   'release'],
#  ['apple',
#   'watch',
#   'likely',
#   'be',
#   'launched',
#   'on',
#   'valentine',
#   's',
#   'day',
#   'plus',
#   'first',
#   'apple',
#   'watch',
#   'accessory',
#   'to',
#   'be',
#   'showcased',
#   'in',
#   'ces',
#   '2015'],
#  ['your',
#   'apple',
#   'watch',
#   'might',
#   'be',
#   'ready',
#   'just',
#   'in',
#   'time',
#   'for',
#   'valentine',
#   's',
#   'day'],
#  ['rumor',
#   'apple',
#   'watch',
#   'production',
#   'gearing',
#   'up',
#   'for',
#   'valentine',
#   's',
#   'day',
#   'release',
#   'with',
#   'high',
#   'prices'],
#  ['valentine',
#   's',
#   'day',
#   '2015',
#   'may',
#   'be',
#   'the',
#   'apple',
#   'watch',
#   'release',
#   'target'],
#  ['kgi',
#   'iphone',
#   'sales',
#   'forecast',
#   'at',
#   '73m',
#   'for',
#   'q4',
#   'ahead',
#   'of',
#   'apple',
#   'watch',
#   'debut',
#   'in',
#   'march',
#   '12',
#   'macbook',
#   'air',
#   'in',
#   'q1'],
#  ['apple',
#   'watch',
#   'may',
#   'go',
#   'on',
#   'sale',
#   'in',
#   'march',
#   'according',
#   'to',
#   'analyst'],
#  ['the',
#   'world',
#   's',
#   'most',
#   'accurate',
#   'apple',
#   'analyst',
#   'says',
#   'the',
#   'apple',
#   'watch',
#   'is',
#   'coming',
#   'in',
#   'march'],
#  ['apple',
#   'watch',
#   'shipments',
#   'to',
#   'start',
#   'in',
#   'march',
#   '12in',
#   'new',
#   'macbook',
#   'air',
#   'expected',
#   'to',
#   'be',
#   'launched',
#   'in',
#   'same',
#   'quarter'],
#  ['apple',
#   'reported',
#   'to',
#   'begin',
#   'shipping',
#   'apple',
#   'watch',
#   'in',
#   'march',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   'in',
#   'early',
#   '2015'],
#  ['apple',
#   'watch',
#   'to',
#   'go',
#   'on',
#   'sale',
#   'in',
#   'march',
#   'claims',
#   'analyst'],
#  ['new',
#   'report',
#   'tips',
#   'apple',
#   'watch',
#   'release',
#   'in',
#   'march',
#   '12in',
#   'macbook',
#   'air',
#   'in',
#   'q1'],
#  ['apple',
#   'watch',
#   'on',
#   'your',
#   'wrist',
#   'in',
#   'march',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   'set',
#   'for',
#   'q1',
#   'launch',
#   'analyst'],
#  ['analyst',
#   'confirms',
#   'apple',
#   'watch',
#   'and',
#   '12',
#   'inch',
#   'macbook',
#   'air',
#   's',
#   'q1',
#   '2015',
#   'launch'],
#  ['apple',
#   'struggled',
#   'to',
#   'find',
#   'purpose',
#   'for',
#   'apple',
#   'watch',
#   'after',
#   'many',
#   'planned',
#   'health',
#   'features',
#   'were',
#   'cut',
#   '5',
#   'million',
#   'units',
#   'ordered'],
#  ['apple',
#   'scrapped',
#   'advanced',
#   'apple',
#   'watch',
#   'health',
#   'monitoring',
#   'features',
#   'due',
#   'to',
#   'reliability',
#   'issues'],
#  ['a',
#   'bunch',
#   'of',
#   'cool',
#   'health',
#   'features',
#   'were',
#   'cut',
#   'from',
#   'the',
#   'apple',
#   'watch',
#   'at',
#   'the',
#   'last',
#   'minute'],
#  ['apple',
#   'was',
#   'forced',
#   'to',
#   'nix',
#   'key',
#   'health',
#   'features',
#   'from',
#   'its',
#   'smartwatch',
#   'report'],
#  ['apple',
#   'watch',
#   'won',
#   't',
#   'be',
#   'the',
#   'digital',
#   'doctor',
#   'it',
#   'could',
#   'have',
#   'been'],
#  ['apple',
#   'cut',
#   'watch',
#   'health',
#   'features',
#   'due',
#   'to',
#   'erratic',
#   'sensors'],
#  ['original',
#   'apple',
#   'watch',
#   'health',
#   'features',
#   'were',
#   'dropped',
#   'due',
#   'to',
#   'consistency',
#   'issues'],
#  ['what', 'exactly', 'is', 'an', 'apple', 'watch', 'for'],
#  ['apple',
#   'watch',
#   'straps',
#   'will',
#   'be',
#   'available',
#   'to',
#   'purchase',
#   'separately',
#   'at',
#   'launch'],
#  ['apple',
#   'watch',
#   'takes',
#   'two',
#   'hours',
#   'to',
#   'charge',
#   'only',
#   'delivers',
#   'notifications',
#   'while',
#   'on',
#   'the',
#   'wrist'],
#  ['sorry',
#   'argentina',
#   's',
#   'president',
#   'didn',
#   't',
#   'actually',
#   'adopt',
#   'a',
#   'jewish',
#   'werewolf'],
#  ['werewolf',
#   'legend',
#   'leads',
#   'to',
#   'jewish',
#   'godson',
#   's',
#   'adoption',
#   'by',
#   'argentina',
#   'president'],
#  ['president',
#   'of',
#   'argentina',
#   'adopts',
#   'boy',
#   'to',
#   'stop',
#   'him',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['president',
#   'of',
#   'argentina',
#   'adopts',
#   'godson',
#   'to',
#   'stop',
#   'him',
#   'from',
#   'turning',
#   'into',
#   'a',
#   'werewolf'],
#  ['argentina',
#   's',
#   'president',
#   'just',
#   'adopted',
#   'a',
#   'son',
#   'so',
#   'he',
#   'won',
#   't',
#   'turn',
#   'into',
#   'a',
#   'werewolf'],
#  ['did',
#   'argentina',
#   's',
#   'president',
#   'adopt',
#   'a',
#   'jewish',
#   'baby',
#   'to',
#   'stop',
#   'it',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['people',
#   'actually',
#   'believed',
#   'argentina',
#   's',
#   'president',
#   'adopted',
#   'a',
#   'jewish',
#   'boy',
#   'to',
#   'stop',
#   'his',
#   'change',
#   'into',
#   'a',
#   'werewolf'],
#  ['there',
#   's',
#   'a',
#   'weird',
#   'story',
#   'going',
#   'around',
#   'about',
#   'how',
#   'argentina',
#   's',
#   'president',
#   'just',
#   'saved',
#   'a',
#   'jewish',
#   'man',
#   'from',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['argentina',
#   's',
#   'president',
#   'adopted',
#   'a',
#   'jewish',
#   'godson',
#   'to',
#   'stop',
#   'him',
#   'from',
#   'turning',
#   'into',
#   'a',
#   'werewolf'],
#  ['the',
#   'story',
#   'of',
#   'the',
#   'argentinean',
#   'president',
#   'werewolves',
#   'and',
#   'seventh',
#   'sons'],
#  ['werewolf', 'legend', 'leads', 'argentine', 'president', 'to', 'adopt'],
#  ['argentina',
#   's',
#   'president',
#   'adopts',
#   'young',
#   'boy',
#   'so',
#   'he',
#   'won',
#   't',
#   'turn',
#   'into',
#   'werewolf'],
#  ['argentina',
#   'president',
#   'adopts',
#   'jewish',
#   'godson',
#   'for',
#   'first',
#   'time',
#   'in',
#   'country',
#   's',
#   'history'],
#  ['argentina',
#   'president',
#   'christina',
#   'kirchner',
#   'has',
#   'bizarre',
#   'werewolf',
#   'mishap'],
#  ['argentina',
#   's',
#   'president',
#   'cristina',
#   'kirchner',
#   'adopts',
#   'jewish',
#   'godson',
#   'to',
#   'prevent',
#   'him',
#   'turning',
#   'into',
#   'a',
#   'werewolf'],
#  ['president',
#   'of',
#   'argentina',
#   'adopts',
#   'jewish',
#   'boy',
#   'to',
#   'stop',
#   'him',
#   'turning',
#   'into',
#   'werewolf'],
#  ['president',
#   'of',
#   'argentina',
#   'adopts',
#   'jewish',
#   'godson',
#   'to',
#   'stop',
#   'him',
#   'turning',
#   'into',
#   'a',
#   'werewolf'],
#  ['argentina',
#   's',
#   'president',
#   'adopts',
#   'jewish',
#   'godson',
#   'to',
#   'counteract',
#   'werewolf',
#   'legend'],
#  ['argentina',
#   's',
#   'president',
#   'didn',
#   't',
#   'adopt',
#   'a',
#   'jewish',
#   'child',
#   'to',
#   'avoid',
#   'becoming',
#   'a',
#   'werewolf',
#   'so',
#   'what',
#   'did',
#   'she',
#   'do'],
#  ['argentina',
#   's',
#   'president',
#   'adopts',
#   'boy',
#   'to',
#   'end',
#   'werewolf',
#   'curse'],
#  ['argentine',
#   'president',
#   'takes',
#   'on',
#   'godson',
#   'but',
#   'not',
#   'to',
#   'keep',
#   'werewolf',
#   'at',
#   'bay'],
#  ['argentina',
#   'president',
#   'adopts',
#   'young',
#   'jewish',
#   'boy',
#   'as',
#   'godson',
#   'to',
#   'prevent',
#   'him',
#   'from',
#   'turning',
#   'into',
#   'werewolf'],
#  ['argentina',
#   's',
#   'president',
#   'adopts',
#   'jewish',
#   'boy',
#   'to',
#   'keep',
#   'him',
#   'from',
#   'turning',
#   'into',
#   'a',
#   'werewolf'],
#  ['seventh', 'sons', 'will', 'turn', 'into', 'werewolves'],
#  ['argentina',
#   's',
#   'president',
#   'adopts',
#   'godson',
#   'to',
#   'prevent',
#   'him',
#   'becoming',
#   'a',
#   'werewolf'],
#  ['no',
#   'argentina',
#   's',
#   'president',
#   'did',
#   'not',
#   'adopt',
#   'a',
#   'jewish',
#   'child',
#   'to',
#   'stop',
#   'him',
#   'turning',
#   'into',
#   'a',
#   'werewolf'],
#  ['argentinian',
#   'president',
#   'cristina',
#   'kirchner',
#   'adopts',
#   'jewish',
#   'boy',
#   'to',
#   'protect',
#   'him',
#   'from',
#   'werewolf',
#   'stigma'],
#  ['adopting',
#   'potential',
#   'werewolves',
#   'is',
#   'routine',
#   'business',
#   'for',
#   'argentine',
#   'presidents'],
#  ['did',
#   'argentina',
#   's',
#   'president',
#   'adopt',
#   'a',
#   'jewish',
#   'boy',
#   'to',
#   'save',
#   'him',
#   'from',
#   'life',
#   'as',
#   'a',
#   'werewolf'],
#  ['boy',
#   '16',
#   'secretly',
#   'films',
#   'sex',
#   'with',
#   'teacher',
#   'then',
#   'uploads',
#   'it',
#   'to',
#   'whatsapp'],
#  ['this',
#   'woman',
#   'is',
#   'wrongly',
#   'being',
#   'called',
#   'a',
#   'sexual',
#   'predator',
#   'after',
#   'her',
#   'private',
#   'sex',
#   'tape',
#   'was',
#   'used',
#   'for',
#   'a',
#   'hoax'],
#  ['has',
#   'this',
#   'argentine',
#   'woman',
#   'fallen',
#   'victim',
#   'to',
#   'a',
#   'cruel',
#   'online',
#   'hoax',
#   'adult',
#   'video',
#   'claiming',
#   'to',
#   'show',
#   'teacher',
#   'having',
#   'sex',
#   'with',
#   'pupil',
#   'isn',
#   't',
#   'all',
#   'it',
#   'seems'],
#  ['female',
#   'teacher',
#   'facing',
#   'sack',
#   'after',
#   'making',
#   'sex',
#   'tape',
#   'with',
#   'teenager'],
#  ['teacher',
#   'sex',
#   'tape',
#   'exposed',
#   'as',
#   'a',
#   'fake',
#   'after',
#   'internet',
#   'detectives',
#   'trace',
#   'the',
#   'origin',
#   'of',
#   'pornographic',
#   'clip'],
#  ['teacher',
#   'suspended',
#   'after',
#   'sex',
#   'session',
#   'with',
#   'teen',
#   'pupil',
#   'ends',
#   'up',
#   'on',
#   'hardcore',
#   'porn',
#   'website'],
#  ['lucita',
#   'sandoval',
#   'sex',
#   'tape',
#   'hoax',
#   'viral',
#   'argentine',
#   'video',
#   'features',
#   'college',
#   'student',
#   'not',
#   '16',
#   'year',
#   'old',
#   'boy'],
#  ['no', 'banksy', 'has', 'not', 'been', 'arrested', 'sigh'],
#  ['graffiti',
#   'artist',
#   'banksy',
#   'arrested',
#   'in',
#   'london',
#   'identity',
#   'revealed'],
#  ['everybody',
#   'relax',
#   'banksy',
#   'wasn',
#   't',
#   'arrested',
#   'and',
#   'exposed',
#   'as',
#   'a',
#   '35',
#   'year',
#   'old',
#   'man'],
#  ['street', 'artist', 'banksy', 'arrested', 'again'],
#  ['a',
#   'bunch',
#   'of',
#   'people',
#   'thought',
#   'banksy',
#   'got',
#   'arrested',
#   'but',
#   'it',
#   'was',
#   'a',
#   'hoax'],
#  ['everyone', 'chill', 'banksy', 'has', 'not', 'been', 'arrested'],
#  ['met', 'police', 'denies', 'reports', 'of', 'banksy', 'arrest'],
#  ['once',
#   'again',
#   'the',
#   'banksy',
#   'arrest',
#   'is',
#   'a',
#   'giant',
#   'hoax',
#   'repeat',
#   'a',
#   'hoax'],
#  ['banksy',
#   'arrested',
#   'real',
#   'identity',
#   'revealed',
#   'is',
#   'the',
#   'same',
#   'hoax',
#   'from',
#   'last',
#   'year'],
#  ['hoax',
#   'banksy',
#   'arrested',
#   'in',
#   'london',
#   'story',
#   'dupes',
#   'the',
#   'internet',
#   'again'],
#  ['banksy',
#   'not',
#   'arrested',
#   'internet',
#   'duped',
#   'by',
#   'fake',
#   'report',
#   'claiming',
#   'artist',
#   's',
#   'identity',
#   'revealed'],
#  ['no', 'banksy', 'hasn', 't', 'been', 'arrested'],
#  ['calm',
#   'down',
#   'everyone',
#   'banksy',
#   'hasn',
#   't',
#   'been',
#   'arrested',
#   '9',
#   'clues',
#   'that',
#   'it',
#   's',
#   'a',
#   'hoax'],
#  ['banksy',
#   'arrest',
#   'hoax',
#   'us',
#   'website',
#   'claims',
#   'street',
#   'artist',
#   'caught',
#   'in',
#   'watford'],
#  ['senior',
#   'western',
#   'intelligence',
#   'official',
#   'confirms',
#   'london',
#   'rapper',
#   'abdel',
#   'majed',
#   'abdel',
#   'bary',
#   'is',
#   'a',
#   'suspect',
#   'in',
#   'the',
#   'foley',
#   'killing'],
#  ['james',
#   'foley',
#   'killer',
#   'jihadi',
#   'john',
#   'believed',
#   'to',
#   'be',
#   'former',
#   'london',
#   'rapper',
#   'abdel',
#   'majed',
#   'abdel',
#   'bary'],
#  ['british', 'rapper', 'a', 'suspect', 'in', 'isis', 'beheading'],
#  ['former',
#   'british',
#   'rapper',
#   'reportedly',
#   'under',
#   'investigation',
#   'for',
#   'james',
#   'foley',
#   'beheading'],
#  ['the',
#   'rapper',
#   'the',
#   'hacker',
#   'and',
#   'the',
#   'terror',
#   'travel',
#   'guide',
#   'writer',
#   'is',
#   'one',
#   'of',
#   'these',
#   'british',
#   'extremists',
#   'jihadi',
#   'john',
#   'three',
#   'potential',
#   'islamic',
#   'state',
#   'beatles',
#   'emerge',
#   'as',
#   'mi5',
#   'zeroes',
#   'in',
#   'on',
#   'murderer',
#   'who',
#   'beheaded',
#   'u',
#   's',
#   'journalist',
#   'james',
#   'foley'],
#  ['abdel',
#   'majed',
#   'abdel',
#   'bary',
#   'in',
#   'foley',
#   'beheading',
#   'london',
#   'rapper',
#   'songs',
#   'help',
#   'identify',
#   'him'],
#  ['us',
#   'uk',
#   'eye',
#   'rapper',
#   'as',
#   'british',
#   'born',
#   'militant',
#   'who',
#   'beheaded',
#   'journalist',
#   'james',
#   'foley'],
#  ['british', 'intelligence', 'has', 'identified', 'foley', 's', 'killer'],
#  ['l',
#   'jinny',
#   'london',
#   'rapper',
#   'turned',
#   'jihadist',
#   'believed',
#   'to',
#   'be',
#   'under',
#   'investigation',
#   'for',
#   'james',
#   'foley',
#   'beheading'],
#  ['abdel',
#   'majed',
#   'abdel',
#   'bary',
#   'london',
#   'rapper',
#   'identified',
#   'as',
#   'isis',
#   'militant',
#   'who',
#   'beheaded',
#   'james',
#   'foley'],
#  ['london',
#   'hip',
#   'hop',
#   'artist',
#   'abdel',
#   'majed',
#   'abdel',
#   'bary',
#   'key',
#   'suspect',
#   'in',
#   'hunt',
#   'for',
#   'killer',
#   'of',
#   'american',
#   'journalist',
#   'james',
#   'foley'],
#  ['abdel',
#   'majed',
#   'abdel',
#   'bary',
#   'emerges',
#   'as',
#   'suspect',
#   'in',
#   'foley',
#   'beheading'],
#  ['british',
#   'born',
#   'rapper',
#   'is',
#   'main',
#   'suspect',
#   'in',
#   'search',
#   'for',
#   'isis',
#   'jihadist',
#   'who',
#   'beheaded',
#   'james',
#   'foley'],
#  ['rapper',
#   'identified',
#   'as',
#   'james',
#   'foley',
#   's',
#   'executioner',
#   'reports'],
#  ['rapper',
#   'identified',
#   'as',
#   'james',
#   'foley',
#   's',
#   'executioner',
#   'reports'],
#  ['l',
#   'jinny',
#   'abdel',
#   'majed',
#   'abdel',
#   'bary',
#   'uk',
#   'rapper',
#   'suspected',
#   'in',
#   'james',
#   'foley',
#   'killing',
#   'reports'],
#  ['gateway', 'pundit'],
#  ['james',
#   'foley',
#   'executioner',
#   'said',
#   'identified',
#   'as',
#   'british',
#   'rapper',
#   'read',
#   'more',
#   'james',
#   'foley',
#   'executioner',
#   'said',
#   'identified',
#   'as',
#   'british',
#   'rapper'],
#  ['gcpd', 'solved', 'stolen', 'batmobile', 'case'],
#  ['holy', 'theft', 'batmobile', 'stolen', 'from', 'batman', 'v', 'superman'],
#  ['batmobile',
#   'rumored',
#   'to',
#   'have',
#   'been',
#   'stolen',
#   'from',
#   'batman',
#   'v',
#   'superman',
#   'dawn',
#   'of',
#   'justice',
#   'set'],
#  ['detroit',
#   'police',
#   'issue',
#   'statement',
#   'that',
#   'the',
#   'batmobile',
#   'is',
#   'safe'],
#  ['was', 'the', 'batmobile', 'stolen', 'in', 'detroit'],
#  ['the',
#   'batmobile',
#   'might',
#   'have',
#   'been',
#   'stolen',
#   'in',
#   'detroit',
#   'update',
#   'nope'],
#  ['batman', 'vs', 'superman', 'batmobile', 'stolen'],
#  ['the', 'case', 'of', 'the', 'stolen', 'batmobile', 'has', 'been', 'solved'],
#  ['zack',
#   'snyder',
#   'makes',
#   'fun',
#   'of',
#   'stolen',
#   'batmobile',
#   'rumor',
#   'with',
#   'new',
#   'image'],
#  ['has',
#   'the',
#   'batman',
#   'vs',
#   'superman',
#   'batmobile',
#   'been',
#   'stolen',
#   'in',
#   'detroit',
#   'update'],
#  ['update',
#   'batman',
#   'v',
#   'superman',
#   'batmobile',
#   'reportedly',
#   'stolen',
#   'by',
#   'shocker',
#   'detroit',
#   'locals'],
#  ['it',
#   's',
#   'back',
#   'the',
#   'incredible',
#   'new',
#   'batmobile',
#   'takes',
#   'a',
#   'spin',
#   'around',
#   'detroit',
#   'after',
#   'rumors',
#   'it',
#   'had',
#   'been',
#   'stolen'],
#  ['at',
#   'cbs',
#   'detroit',
#   'fan',
#   'site',
#   'scuttlebutt',
#   'is',
#   'enough',
#   'to',
#   'report',
#   'false',
#   'batmobile',
#   'theft'],
#  ['batmobile', 'stolen', 'in', 'detroit', 'good', 'one', 'joker'],
#  ['batmobile',
#   'stolen',
#   'from',
#   'batman',
#   'v',
#   'superman',
#   'dawn',
#   'of',
#   'justice',
#   'set',
#   'report',
#   'claims',
#   'that',
#   'one',
#   'of',
#   'the',
#   'batmobile',
#   'models',
#   'is',
#   'missing',
#   'detroit',
#   'locals',
#   'responsible'],
#  ['zack',
#   'snyder',
#   's',
#   'batman',
#   'v',
#   'superman',
#   'dawn',
#   'of',
#   'justice',
#   'stolen',
#   'batmobile',
#   'rumor',
#   'put',
#   'to',
#   'rest'],
#  ['zack',
#   'snyder',
#   'kills',
#   'stolen',
#   'batmobile',
#   'rumor',
#   'with',
#   'great',
#   'photo'],
#  ['zack', 'snyder', 'responds', 'to', 'fake', 'stolen', 'batmobile', 'report'],
#  ['lol',
#   'rich',
#   'johnston',
#   'says',
#   'the',
#   'batmobile',
#   'has',
#   'been',
#   'stolen',
#   'in',
#   'detroit'],
#  ['batmobile',
#   'not',
#   'stolen',
#   'mtv',
#   'contest',
#   'prize',
#   'remains',
#   'unclaimed'],
#  ['batmobile', 'wasn', 't', 'stolen', 'cops'],
#  ['batmobile',
#   'stolen',
#   'from',
#   'batman',
#   'v',
#   'superman',
#   'dawn',
#   'of',
#   'justice',
#   'set',
#   'zack',
#   'snyder',
#   'knows',
#   'who',
#   'did',
#   'it'],
#  ['boston',
#   'com',
#   'retracts',
#   'claim',
#   'about',
#   'racist',
#   'email',
#   'from',
#   'professor'],
#  ['update',
#   'did',
#   'boston',
#   'com',
#   'make',
#   'up',
#   'this',
#   'story',
#   'about',
#   'the',
#   'web',
#   'sheriff',
#   'ben',
#   'edelman',
#   'sending',
#   'racist',
#   'emails'],
#  ['boston',
#   'com',
#   'pulls',
#   'story',
#   'accusing',
#   'prof',
#   'of',
#   'sending',
#   'racist',
#   'emails'],
#  ['the', 'washington', 'post', 'is', 'now', 'free', 'on', 'amazon', 'kindles'],
#  ['jeff',
#   'bezos',
#   'is',
#   'planning',
#   'to',
#   'make',
#   'the',
#   'washington',
#   'post',
#   'pre',
#   'loaded',
#   'on',
#   'every',
#   'kindle',
#   'hdx'],
#  ['justin',
#   'bieber',
#   'helps',
#   'defend',
#   'russian',
#   'fisherman',
#   'from',
#   'bear'],
#  ['justin',
#   'bieber',
#   'saved',
#   'a',
#   'guy',
#   'getting',
#   'mauled',
#   'by',
#   'a',
#   'bear'],
#  ['man',
#   'mauled',
#   'by',
#   'bear',
#   'says',
#   'he',
#   's',
#   'only',
#   'alive',
#   'thanks',
#   'to',
#   'justin',
#   'bieber'],
#  ['justin',
#   'bieber',
#   's',
#   'baby',
#   'saves',
#   'man',
#   'from',
#   'violent',
#   'bear',
#   'attack'],
#  ['justin', 'bieber', 'saves', 'man', 'from', 'bear', 'attack'],
#  ['justin',
#   'bieber',
#   'ringtone',
#   'saves',
#   'man',
#   'being',
#   'mauled',
#   'by',
#   'bear'],
#  ['justin',
#   'bieber',
#   'ringtone',
#   'saved',
#   'a',
#   'russian',
#   'fisherman',
#   'during',
#   'a',
#   'bear',
#   'attack'],
#  ['bieber', 'ringtone', 'scares', 'bear', 'saves', 'man', 's', 'life'],
#  ['a',
#   'russian',
#   'guy',
#   'says',
#   'his',
#   'justin',
#   'bieber',
#   'ringtone',
#   'saved',
#   'him',
#   'from',
#   'a',
#   'bear',
#   'attack'],
#  ['justin', 'bieber', 'saved', 'this', 'guy', 'from', 'a', 'bear', 'attack'],
#  ['finally',
#   'proof',
#   'that',
#   'justin',
#   'bieber',
#   'is',
#   'unbearable',
#   'russian',
#   'fisherman',
#   'saved',
#   'from',
#   'bear',
#   'attack',
#   'when',
#   'ringtone',
#   'featuring',
#   'one',
#   'of',
#   'the',
#   'pop',
#   'brat',
#   's',
#   'songs',
#   'scares',
#   'it',
#   'away'],
#  ['man',
#   'saved',
#   'from',
#   'bear',
#   'attack',
#   'thanks',
#   'to',
#   'his',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['fisherman',
#   'saved',
#   'from',
#   'deadly',
#   'bear',
#   'attack',
#   'by',
#   'his',
#   'justin',
#   'bieber',
#   'ringtone'],
#  ['justin',
#   'bieber',
#   'scares',
#   'off',
#   'grizzly',
#   'bear',
#   'and',
#   'saves',
#   'fisherman',
#   'from',
#   'a',
#   'mauling'],
#  ['justin',
#   'bieber',
#   'basically',
#   'saves',
#   'a',
#   'russian',
#   'man',
#   'from',
#   'a',
#   'bear'],
#  ['man',
#   'saved',
#   'from',
#   'bear',
#   'attack',
#   'when',
#   'his',
#   'justin',
#   'bieber',
#   'ringtones',
#   'goes',
#   'off',
#   'sending',
#   'bear',
#   'fleeing'],
#  ['justin', 'bieber', 'ringtone', 'startles', 'bear'],
#  ['justin',
#   'bieber',
#   'ringtone',
#   'saves',
#   'russian',
#   'fisherman',
#   'from',
#   'bear',
#   'attack'],
#  ['bear',
#   'attack',
#   'foiled',
#   'by',
#   'justin',
#   'bieber',
#   's',
#   'music',
#   'a',
#   'story',
#   'too',
#   'good',
#   'to',
#   'check'],
#  ['justin',
#   'bieber',
#   'ringtone',
#   'saves',
#   'russian',
#   'man',
#   'from',
#   'bear',
#   'attack'],
#  ['unbearable',
#   'man',
#   'fends',
#   'off',
#   'bear',
#   'attack',
#   'by',
#   'playing',
#   'justin',
#   'bieber',
#   'song'],
#  ['justin',
#   'bieber',
#   'ringtone',
#   'scares',
#   'bear',
#   'saves',
#   'russian',
#   'fisherman'],
#  ['sugarhill', 'gang', 'rapper', 'big', 'bank', 'hank', 'dead', 'at', '57'],
#  ['sugarhill', 'gang', 'rapper', 'big', 'bank', 'hank', 'dies', 'at', '57'],
#  ['big',
#   'bank',
#   'hank',
#   'us',
#   'rapper',
#   'and',
#   'sugarhill',
#   'gang',
#   'founder',
#   'member',
#   'dies',
#   'at',
#   '57'],
#  ['sugarhill',
#   'gang',
#   'rapper',
#   'big',
#   'bank',
#   'hank',
#   'dies',
#   'at',
#   'age',
#   '57'],
#  ['sugarhill', 'gang', 'co', 'founder', 'big', 'bank', 'hank', 'dies'],
#  ['sugarhill', 'gang', 's', 'big', 'bank', 'hank', 'dead', 'at', '57'],
#  ['big',
#   'bank',
#   'hank',
#   'co',
#   'founder',
#   'of',
#   'the',
#   'sugarhill',
#   'gang',
#   'has',
#   'died'],
#  ['big',
#   'bank',
#   'hank',
#   'dead',
#   'sugarhill',
#   'gang',
#   'member',
#   'and',
#   'rapper',
#   'dies',
#   'aged',
#   '57'],
#  ['big',
#   'bank',
#   'hank',
#   'of',
#   'the',
#   'sugarhill',
#   'gang',
#   'is',
#   'dead',
#   'at',
#   '57'],
#  ['sugarhill', 'gang', 'rapper', 'big', 'bank', 'hank', 'dies', 'aged', '57'],
#  ['sugarhill', 'gang', 'rapper', 'big', 'bank', 'hank', 'dies', 'at', '57'],
#  ['sugarhill', 'gang', 's', 'big', 'bank', 'hank', 'dead', 'at', '57'],
#  ['rapper',
#   'big',
#   'bank',
#   'hank',
#   'of',
#   'sugarhill',
#   'gang',
#   'dies',
#   'at',
#   '57'],
#  ['big',
#   'bank',
#   'hank',
#   'of',
#   'pioneering',
#   'rap',
#   'group',
#   'sugarhill',
#   'gang',
#   'has',
#   'died'],
#  ['russians', 'bag', 'better', 'bigfoot', 'footage'],
#  ['according',
#   'to',
#   'some',
#   'russians',
#   'this',
#   'dark',
#   'figure',
#   'stumbling',
#   'through',
#   'the',
#   'snowy',
#   'woods',
#   'is',
#   'a',
#   'yeti',
#   'and',
#   'they',
#   'even',
#   'have',
#   'a',
#   'footprint',
#   'hmmmmm'],
#  ['bigfoot',
#   'strolls',
#   'through',
#   'a',
#   'russian',
#   'forest',
#   'at',
#   'least',
#   'that',
#   's',
#   'the',
#   'claim',
#   'video'],
#  ['russian',
#   'yeti',
#   'or',
#   'bigfoot',
#   'hoax',
#   'new',
#   'footage',
#   'sparks',
#   'debate'],
#  ['is',
#   'this',
#   'proof',
#   'of',
#   'bigfoot',
#   'new',
#   'yeti',
#   'video',
#   'shows',
#   'giant',
#   'hairy',
#   'beast',
#   'walking',
#   'through',
#   'forest'],
#  ['vladimir',
#   'putin',
#   'gives',
#   'speech',
#   'on',
#   'dangers',
#   'of',
#   'military',
#   'aggression'],
#  ['no', 'a', 'bird', 'didn', 't', 'poop', 'on', 'vladimir', 'putin'],
#  ['watch',
#   'bird',
#   'launches',
#   'airstrike',
#   'on',
#   'putin',
#   's',
#   'shoulder',
#   'updated'],
#  ['a',
#   'bunch',
#   'of',
#   'folks',
#   'are',
#   'passing',
#   'around',
#   'this',
#   'hoax',
#   'video',
#   'of',
#   'a',
#   'bird',
#   'pooping',
#   'on',
#   'vladimir',
#   'putin'],
#  ['no',
#   'vladimir',
#   'putin',
#   'did',
#   'not',
#   'get',
#   'pooped',
#   'on',
#   'by',
#   'a',
#   'bird',
#   'during',
#   'a',
#   'first',
#   'world',
#   'war',
#   'speech'],
#  ['vladimir', 'putin', 'bird', 'poop', 'video', 'is', 'fake'],
#  ['if', 'only', 'a', 'bird', 'really', 'did', 'poop', 'on', 'putin'],
#  ['the',
#   'video',
#   'of',
#   'a',
#   'bird',
#   'pooping',
#   'on',
#   'vladimir',
#   'putin',
#   'is',
#   'a',
#   'hoax'],
#  ['news', 'sites', 'fall', 'for', 'putin', 'bird', 'dropping', 'video'],
#  ['federal', 'judge', 'enough', 'with', 'the', 'stupid', 'names'],
#  ['terrorist',
#   'plot',
#   'targeting',
#   'black',
#   'friday',
#   'shoppers',
#   'uncovered'],
#  ['bih',
#   'seven',
#   'primary',
#   'school',
#   'students',
#   'pregnant',
#   'after',
#   'five',
#   'day',
#   'excursion'],
#  ['seven',
#   'girls',
#   'as',
#   'young',
#   'as',
#   '13',
#   'become',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven', 'teenage', 'girls', 'get', 'pregnant', 'on', 'school', 'trip'],
#  ['media',
#   'fooled',
#   'again',
#   'story',
#   'claims',
#   '7',
#   'of',
#   '28',
#   'girls',
#   'on',
#   'school',
#   'trip',
#   'came',
#   'home',
#   'pregnant'],
#  ['you', 'all', 'had', 'an', 'abortion', 'google', 'translate'],
#  ['parents',
#   'are',
#   'furious',
#   'after',
#   'seven',
#   'girls',
#   'aged',
#   '13',
#   '14',
#   'fall',
#   'pregnant',
#   'on',
#   'a',
#   'school',
#   'trip'],
#  ['seven',
#   'girls',
#   'fall',
#   'pregnant',
#   'after',
#   'five',
#   'day',
#   'school',
#   'trip',
#   'in',
#   'bosnia',
#   'and',
#   'herzegovina'],
#  ['parents',
#   'anger',
#   'after',
#   'seven',
#   'bosnian',
#   'schoolgirls',
#   'aged',
#   '13',
#   'and',
#   '14',
#   'fall',
#   'pregnant',
#   'on',
#   'class',
#   'trip'],
#  ['rare',
#   'case',
#   'seven',
#   'bosnian',
#   'girls',
#   'aged',
#   '13',
#   'and',
#   '14',
#   'fall',
#   'pregnant',
#   'after',
#   'five',
#   'day',
#   'school',
#   'trip',
#   'parents',
#   'outraged',
#   'after',
#   'school',
#   'cites',
#   'parental',
#   'neglect'],
#  ['bosnia',
#   'seven',
#   'underage',
#   'girls',
#   'return',
#   'from',
#   'five',
#   'day',
#   'school',
#   'trip',
#   'pregnant'],
#  ['seven',
#   'high',
#   'school',
#   'girls',
#   'get',
#   'pregnant',
#   'on',
#   'five',
#   'day',
#   'school',
#   'trip',
#   'parents',
#   'outraged'],
#  ['seven',
#   'girls',
#   'fall',
#   'pregnant',
#   'after',
#   'five',
#   'day',
#   'school',
#   'trip',
#   'in',
#   'bosnia',
#   'and',
#   'herzegovina'],
#  ['7', 'bosnian', 'teens', 'get', 'pregnant', 'on', 'school', 'trip'],
#  ['7',
#   'teen',
#   'girls',
#   'get',
#   'pregnant',
#   'on',
#   'school',
#   'trip',
#   'read',
#   'more',
#   'at',
#   'http',
#   'www',
#   'wnd',
#   'com2014127',
#   'teen',
#   'girls',
#   'get',
#   'pregnant',
#   'on',
#   'school',
#   'tripf5filod6yfpaspv9',
#   '99'],
#  ['accused',
#   'boston',
#   'marathon',
#   'bomber',
#   'severely',
#   'injured',
#   'in',
#   'prison',
#   'may',
#   'never',
#   'walk',
#   'or',
#   'talk',
#   'again'],
#  ['dzhokhar',
#   'tsarnaev',
#   'beaten',
#   'in',
#   'prison',
#   'satirical',
#   'site',
#   'claims',
#   'boston',
#   'marathon',
#   'bombing',
#   'suspect',
#   'blinded',
#   'and',
#   'paralyzed'],
#  ['source', 'tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['tom',
#   'brokaw',
#   'wants',
#   'brian',
#   'williams',
#   'out',
#   'nbc',
#   'legend',
#   'furious',
#   'at',
#   'iraq',
#   'war',
#   'lie',
#   'as',
#   'it',
#   's',
#   'claimed',
#   'executives',
#   'warned',
#   'anchor',
#   'to',
#   'stop',
#   'exaggerating',
#   'the',
#   'story',
#   'in',
#   'the',
#   'past'],
#  ['nbc',
#   's',
#   'tom',
#   'brokaw',
#   'reportedly',
#   'wants',
#   'brian',
#   'williams',
#   'fired',
#   'over',
#   'fabricated',
#   'iraq',
#   'helicopter',
#   'story'],
#  ['tom',
#   'brokaw',
#   'wants',
#   'brian',
#   'williams',
#   'fired',
#   'over',
#   'iraq',
#   'helicopter',
#   'story',
#   'report'],
#  ['tom', 'brokaw', 'wants', 'brian', 'williams', 'fired'],
#  ['dna',
#   'results',
#   'confirm',
#   'michael',
#   'jackson',
#   'is',
#   'biological',
#   'father',
#   'of',
#   'bruno',
#   'mars'],
#  ['fake',
#   'news',
#   'report',
#   'claims',
#   'michael',
#   'jackson',
#   'is',
#   'father',
#   'of',
#   'bruno',
#   'mars'],
#  ['no', 'michael', 'jackson', 'isn', 't', 'bruno', 'mars', 'dad'],
#  ['woman',
#   'says',
#   'she',
#   'gave',
#   'her',
#   'cheating',
#   'man',
#   'a',
#   'printout',
#   'of',
#   'his',
#   'dms',
#   'for',
#   'christmas'],
#  ['this',
#   'woman',
#   'exposed',
#   'her',
#   'cheating',
#   'boyfriend',
#   'with',
#   'a',
#   'brilliant',
#   'christmas',
#   'gift'],
#  ['woman',
#   'catches',
#   'husband',
#   'cheating',
#   'with',
#   'her',
#   'twin',
#   'humiliates',
#   'them'],
#  ['spurned',
#   'wife',
#   'leaves',
#   'cheating',
#   'husband',
#   'and',
#   'twin',
#   'naked',
#   'in',
#   'busy',
#   'car',
#   'park'],
#  ['woman',
#   'ting',
#   'su',
#   'finds',
#   'husband',
#   'cheating',
#   'with',
#   'her',
#   'own',
#   'twin',
#   'gets',
#   'spectacular',
#   'revenge'],
#  ['scorned',
#   'wife',
#   'leaves',
#   'love',
#   'rat',
#   'husband',
#   'and',
#   'twin',
#   'sister',
#   'naked',
#   'in',
#   'car',
#   'park'],
#  ['china',
#   'satirical',
#   'site',
#   'warns',
#   'citizens',
#   'over',
#   'name',
#   'choices'],
#  ['chinese',
#   'state',
#   'media',
#   'warns',
#   'people',
#   'to',
#   'stop',
#   'calling',
#   'themselves',
#   'dumbledore'],
#  ['tips', 'for', 'chinese', 'choosing', 'an', 'english', 'name'],
#  ['how',
#   'did',
#   'fake',
#   'chinese',
#   'news',
#   'site',
#   'dupe',
#   'washington',
#   'post',
#   'atlantic',
#   'bbc'],
#  ['chinese',
#   'advised',
#   'to',
#   'choose',
#   'british',
#   'sounding',
#   'names',
#   'to',
#   'get',
#   'ahead'],
#  ['the', 'chinese', 'guide', 'to', 'avoiding', 'a', 'bad', 'english', 'name'],
#  ['satirical',
#   'news',
#   'site',
#   'attacks',
#   'china',
#   's',
#   'weird',
#   'english',
#   'names'],
#  ['unlucky', 'in', 'love', 'man', 'chops', 'off', 'own', 'penis'],
#  ['unlucky',
#   'in',
#   'love',
#   'man',
#   'chops',
#   'off',
#   'own',
#   'penis',
#   'because',
#   'he',
#   'was',
#   'fed',
#   'up',
#   'with',
#   'not',
#   'having',
#   'a',
#   'girlfriend'],
#  ['yang',
#   'hu',
#   'worker',
#   'in',
#   'zhejiang',
#   'cuts',
#   'off',
# ...
#   'certain',
#   'words',
#   'we',
#   'use',
#   'too',
#   'often',
#   'what',
#   's',
#   'yours',
#   'meatless',
#   'mondaysthe',
#   'beatles',
#   'bob',
#   'dylan',
#   'biggie',
#   'smalls',
#   'how',
#   'to',
#   'fix',
#   'gerrymandering',
#   'and',
#   'improve',
#   'american',
#   'politics',
#   'in',
#   'one',
#   'fell',
#   'swoopthe',
#   'very',
#   'funny',
#   'comic',
#   'who',
#   'just',
#   'became',
#   'snl',
#   's',
#   'next',
#   'weekend',
#   'update',
#   'anchor'],
#  ['isis', 'beheads', 'american', 'journalist'],
#  ['james',
#   'foley',
#   'american',
#   'journalist',
#   'james',
#   'wright',
#   'foley',
#   'beheaded',
#   'in',
#   'new',
#   'isis',
#   'terrorist',
#   'video',
#   'breaking',
#   'news'],
#  ['isil',
#   'video',
#   'claims',
#   'beheading',
#   'of',
#   'kidnapped',
#   'journalist',
#   'james',
#   'foley'],
#  ['islamic',
#   'state',
#   'militants',
#   'claim',
#   'to',
#   'have',
#   'killed',
#   'us',
#   'journalist',
#   'james',
#   'foley'],
#  ['obama',
#   'murder',
#   'of',
#   'james',
#   'foley',
#   'shocks',
#   'the',
#   'conscience',
#   'of',
#   'the',
#   'entire',
#   'world'],
#  ['isil', 'claims', 'to', 'behead', 'an', 'american', 'photojournalist'],
#  ['islamic',
#   'state',
#   'claims',
#   'it',
#   'executed',
#   'american',
#   'photojournalist',
#   'james',
#   'foley'],
#  ['obama',
#   'denounces',
#   'killing',
#   'of',
#   'journalist',
#   'james',
#   'foley',
#   'and',
#   'pledges',
#   'justice'],
#  ['isis',
#   'tells',
#   'mother',
#   'on',
#   'rescue',
#   'mission',
#   'you',
#   've',
#   'just',
#   'eaten',
#   'your',
#   'son'],
#  ['isis',
#   'militants',
#   'trick',
#   'mother',
#   'into',
#   'eating',
#   'her',
#   'kidnapped',
#   'son'],
#  ['islamic', 'state', 'fed', 'murdered', 'man', 'to', 'his', 'own', 'mother'],
#  ['isis',
#   'fed',
#   'murdered',
#   'kidnap',
#   'victim',
#   'to',
#   'his',
#   'own',
#   'mother',
#   'after',
#   'she',
#   'travelled',
#   'to',
#   'their',
#   'headquarters',
#   'and',
#   'demanded',
#   'to',
#   'see',
#   'him'],
#  ['there',
#   'is',
#   'no',
#   'limit',
#   'to',
#   'their',
#   'depravity',
#   'islamic',
#   'state',
#   'feed',
#   'mother',
#   'her',
#   'own',
#   'son'],
#  ['after',
#   'isis',
#   'trick',
#   'mum',
#   'into',
#   'eating',
#   'son',
#   '5',
#   'other',
#   'reluctant',
#   'cannibals',
#   'including',
#   'those',
#   'forced',
#   'to',
#   'eat',
#   'own',
#   'body',
#   'parts'],
#  ['isis',
#   'desperate',
#   'mum',
#   'told',
#   'you',
#   've',
#   'just',
#   'eaten',
#   'your',
#   'son',
#   'after',
#   'visiting',
#   'militants',
#   'base',
#   'in',
#   'search',
#   'of',
#   'kidnap',
#   'victim'],
#  ['isis',
#   'blasts',
#   'scorpion',
#   'bombs',
#   'at',
#   'civilian',
#   'areas',
#   'in',
#   'iraq',
#   'mosul',
#   'residents',
#   'living',
#   'in',
#   'fear'],
#  ['is', 'using', 'scorpion', 'bombs', 'to', 'terrify', 'iraqi', 'civilians'],
#  ['isis',
#   'using',
#   'bombs',
#   'containing',
#   'live',
#   'scorpions',
#   'in',
#   'effort',
#   'to',
#   'spread',
#   'panic',
#   'in',
#   'tactic',
#   'used',
#   '2',
#   '000',
#   'years',
#   'ago',
#   'against',
#   'romans'],
#  ['islamic',
#   'state',
#   'using',
#   'scorpion',
#   'bombs',
#   'to',
#   'terrorise',
#   'victims'],
#  ['islamic',
#   'state',
#   'fighters',
#   'detonate',
#   'scorpion',
#   'bombs',
#   'in',
#   'terror',
#   'siege'],
#  ['isis',
#   'launch',
#   'scorpion',
#   'bombs',
#   'to',
#   'spread',
#   'panic',
#   'in',
#   'iraq'],
#  ['isis', 'unleash', 'scorpion', 'bombs', 'in', 'iraq'],
#  ['isis',
#   'is',
#   'selling',
#   'the',
#   'body',
#   'of',
#   'james',
#   'foley',
#   'for',
#   '1',
#   'million'],
#  ['isis', 'wants', '1m', 'for', 'foley', 's', 'body'],
#  ['isis',
#   'is',
#   'reportedly',
#   'trying',
#   'to',
#   'sell',
#   'james',
#   'foley',
#   's',
#   'remains',
#   'for',
#   '1',
#   'million'],
#  ['isis',
#   'is',
#   'trying',
#   'to',
#   'sell',
#   'the',
#   'body',
#   'of',
#   'u',
#   's',
#   'hostage',
#   'james',
#   'foley',
#   'for',
#   '1',
#   'million'],
#  ['fresh',
#   'agony',
#   'for',
#   'james',
#   'foley',
#   's',
#   'family',
#   'as',
#   'sick',
#   'isis',
#   'militants',
#   'try',
#   'to',
#   'sell',
#   'them',
#   'his',
#   'headless',
#   'body',
#   'for',
#   '1million'],
#  ['islamic',
#   'state',
#   'trying',
#   'to',
#   'sell',
#   'decapitated',
#   'body',
#   'of',
#   'us',
#   'hostage',
#   'james',
#   'foley',
#   'for',
#   '1',
#   'million'],
#  ['isis',
#   'james',
#   'foley',
#   's',
#   'beheaded',
#   'body',
#   'in',
#   '1m',
#   'humanity',
#   'case',
#   'sale',
#   'offer',
#   'to',
#   'family'],
#  ['james',
#   'foley',
#   'beheading',
#   'isis',
#   'militants',
#   'trying',
#   'to',
#   'sell',
#   'murdered',
#   'hostage',
#   's',
#   'body',
#   'to',
#   'his',
#   'parents',
#   'for',
#   '1m'],
#  ['isis',
#   'reportedly',
#   'wants',
#   '1',
#   'million',
#   'for',
#   'beheaded',
#   'hostage',
#   'james',
#   'foley',
#   's',
#   'corpse'],
#  ['islamic',
#   'state',
#   'attempting',
#   'to',
#   'sell',
#   'james',
#   'foley',
#   's',
#   'body',
#   'for',
#   '1',
#   'million'],
#  ['is',
#   'reportedly',
#   'tries',
#   'to',
#   'sell',
#   'slain',
#   'us',
#   'hostage',
#   's',
#   'body',
#   'for',
#   '1',
#   'million',
#   'read',
#   'more',
#   'is',
#   'reportedly',
#   'tries',
#   'to',
#   'sell',
#   'slain',
#   'us',
#   'hostage',
#   's',
#   'body',
#   'for',
#   '1',
#   'million'],
#  ['islamic',
#   'state',
#   'puts',
#   'james',
#   'foley',
#   's',
#   'body',
#   'up',
#   'for',
#   'sale',
#   'for',
#   '1m'],
#  ['daash',
#   'syria',
#   'announces',
#   'egyptian',
#   'escape',
#   'b',
#   'zakat',
#   'funds',
#   'google',
#   'translate'],
#  ['an',
#   'egyptian',
#   'isis',
#   'treasurer',
#   'stole',
#   '1',
#   'million',
#   'and',
#   'fled',
#   'to',
#   'turkey'],
#  ['isis',
#   'egyptian',
#   'treasurer',
#   'steals',
#   'zakat',
#   'funds',
#   'and',
#   'flees',
#   'to',
#   'turkey'],
#  ['isis',
#   'treasurer',
#   'reportedly',
#   'steals',
#   '1m',
#   'from',
#   'group',
#   'flees',
#   'to',
#   'turkey'],
#  ['israel', 'opens', 'dams', 'floods', 'gaza'],
#  ['palestine',
#   'accuses',
#   'israel',
#   'of',
#   'opening',
#   'dams',
#   'flooding',
#   'gaza',
#   'forcing',
#   'evacuations'],
#  ['the', 'flood', 'libel', 'propagandists', 'of', '2015'],
#  ['hundreds',
#   'of',
#   'palestinians',
#   'flee',
#   'floods',
#   'in',
#   'gaza',
#   'as',
#   'israel',
#   'opens',
#   'dams'],
#  ['israel', 'denies', 'causing', 'gaza', 'floods', 'by', 'opening', 'dams'],
#  ['hundreds',
#   'of',
#   'palestinians',
#   'flee',
#   'as',
#   'israel',
#   'opens',
#   'dams',
#   'into',
#   'gaza',
#   'valley'],
#  ['italian', 'fisherman', 'catches', 'monstrous', '280', 'pound', 'catfish'],
#  ['caught',
#   'a',
#   'catfish',
#   'record',
#   'in',
#   'po',
#   '127',
#   'kg',
#   'and',
#   '2',
#   '67',
#   'meters'],
#  ['giant',
#   '8ft',
#   '9in',
#   'catfish',
#   'weighing',
#   '19',
#   'stone',
#   'caught',
#   'in',
#   'italy',
#   'is',
#   'thought',
#   'to',
#   'be',
#   'the',
#   'biggest',
#   'ever',
#   'reeled',
#   'in',
#   'with',
#   'a',
#   'rod',
#   'and',
#   'line'],
#  ['italian', 'catches', 'huge', 'wels', 'catfish', 'is', 'it', 'a', 'record'],
#  ['enormous',
#   '20',
#   'stone',
#   'catfish',
#   'caught',
#   'with',
#   'fishing',
#   'rod',
#   'in',
#   'italy',
#   'after',
#   '40',
#   'minute',
#   'boat',
#   'battle'],
#  ['280',
#   'pound',
#   'catfish',
#   'fisherman',
#   'makes',
#   'huge',
#   'catch',
#   'in',
#   'italy',
#   'catfish',
#   'could',
#   'set',
#   'record'],
#  ['fisherman',
#   'lands',
#   '19',
#   'stone',
#   'catfish',
#   'which',
#   'could',
#   'be',
#   'biggest',
#   'in',
#   'world',
#   'to',
#   'be',
#   'hooked'],
#  ['monster',
#   'catfish',
#   'which',
#   'looks',
#   'big',
#   'enough',
#   'to',
#   'swallow',
#   'a',
#   'man',
#   'whole',
#   'caught',
#   'in',
#   'italy'],
#  ['surreal',
#   'photos',
#   'of',
#   'fisherman',
#   's',
#   'jaw',
#   'dropping',
#   'catch',
#   'will',
#   'likely',
#   'have',
#   'people',
#   'wondering',
#   'if',
#   'it',
#   's',
#   'real'],
#  ['nun',
#   'complains',
#   'of',
#   'stomach',
#   'pains',
#   'later',
#   'gives',
#   'birth',
#   'to',
#   'baby',
#   'boy'],
#  ['nun',
#   'who',
#   'gave',
#   'birth',
#   'had',
#   'no',
#   'idea',
#   'she',
#   'was',
#   'pregnant'],
#  ['nun', 'gives', 'birth', 'intends', 'to', 'keep', 'baby'],
#  ['nun',
#   'who',
#   'had',
#   'no',
#   'idea',
#   'she',
#   'was',
#   'pregnant',
#   'gives',
#   'birth',
#   'after',
#   'going',
#   'to',
#   'hospital',
#   'with',
#   'stomach',
#   'pains'],
#  ['cloistered',
#   'nun',
#   'has',
#   'a',
#   'stomach',
#   'ache',
#   'hospital',
#   'gives',
#   'birth',
#   'to',
#   'a',
#   'baby',
#   'google',
#   'translate'],
#  ['nun',
#   'complains',
#   'of',
#   'stomach',
#   'pains',
#   'and',
#   'gives',
#   'birth',
#   'sister',
#   'who',
#   'had',
#   'no',
#   'idea',
#   'she',
#   'was',
#   'pregnant',
#   'has',
#   'a',
#   'baby',
#   'boy',
#   'at',
#   'hospital',
#   'in',
#   'italy'],
#  ['nun',
#   'gives',
#   'birth',
#   'to',
#   'surprise',
#   'baby',
#   'after',
#   'complaining',
#   'of',
#   'stomach',
#   'pains'],
#  ['nun',
#   'gives',
#   'birth',
#   'to',
#   'surprise',
#   'baby',
#   'after',
#   'complaining',
#   'of',
#   'stomach',
#   'pains'],
#  ['nun',
#   'has',
#   'surprise',
#   'baby',
#   'after',
#   'complaining',
#   'of',
#   'stomach',
#   'pains'],
#  ['nun',
#   'who',
#   'gave',
#   'birth',
#   'to',
#   'baby',
#   'boy',
#   'after',
#   'suffering',
#   'agonising',
#   'stomach',
#   'pains',
#   'had',
#   'no',
#   'idea',
#   'she',
#   'was',
#   'pregnant'],
#  ['wayward', 'sister', 'nun', 'the', 'wiser', 'about', 'baby'],
#  ['nun',
#   'gives',
#   'birth',
#   'to',
#   'baby',
#   'boy',
#   'after',
#   'suffering',
#   'intense',
#   'stomach',
#   'pains'],
#  ['cloistered',
#   'nun',
#   'gives',
#   'birth',
#   'to',
#   'a',
#   'baby',
#   'the',
#   'convent',
#   'there',
#   'is',
#   'a',
#   'sister',
#   'google',
#   'translate'],
#  ['kim', 'jong', 'un', 'had', 'surgery', 'on', 'fractured', 'ankles'],
#  ['cheese',
#   'blamed',
#   'for',
#   'north',
#   'korean',
#   'leader',
#   'kim',
#   'jong',
#   'un',
#   's',
#   'broken',
#   'ankles'],
#  ['kim', 'had', 'ankle', 'surgery', 'source'],
#  ['kim',
#   'jong',
#   'un',
#   'broke',
#   'both',
#   'ankles',
#   'and',
#   'is',
#   'hospitalized',
#   'report',
#   'claims'],
#  ['kim',
#   'jong',
#   'un',
#   'is',
#   'so',
#   'fat',
#   'from',
#   'eating',
#   'cheese',
#   'that',
#   'he',
#   'has',
#   'broken',
#   'his',
#   'ankles'],
#  ['north',
#   'korean',
#   'leader',
#   'kim',
#   'jong',
#   'un',
#   's',
#   'mystery',
#   'illness',
#   'actually',
#   'two',
#   'broken',
#   'ankles',
#   'newspaper',
#   'says'],
#  ['cheese', 'addiction', 'breaks', 'kim', 'jong', 'un', 's', 'ankles'],
#  ['south',
#   'korea',
#   'kim',
#   'jong',
#   'un',
#   'had',
#   'ankle',
#   'surgery',
#   'to',
#   'remove',
#   'cyst'],
#  ['kim',
#   'jong',
#   'un',
#   'in',
#   'hospital',
#   'with',
#   'two',
#   'fractured',
#   'ankles',
#   'after',
#   'ballooning',
#   'to',
#   'around',
#   '20',
#   'stone',
#   'and',
#   'going',
#   'on',
#   'numerous',
#   'meet',
#   'the',
#   'people',
#   'walkabout',
#   'pr',
#   'stunts'],
#  ['report',
#   'claims',
#   'kim',
#   'jong',
#   'un',
#   'underwent',
#   'surgery',
#   'to',
#   'repair',
#   'fractured',
#   'ankles'],
#  ['kim',
#   'jong',
#   'un',
#   'north',
#   'korean',
#   'leader',
#   'recovering',
#   'from',
#   'ankle',
#   'surgery'],
#  ['north',
#   'korea',
#   'dictator',
#   'kim',
#   'jong',
#   'un',
#   'undergoes',
#   'surgery',
#   'after',
#   'breaking',
#   'both',
#   'ankles',
#   'on',
#   'military',
#   'tour'],
#  ['kim',
#   'jong',
#   'un',
#   'hospitalized',
#   'with',
#   'two',
#   'broken',
#   'ankles',
#   'reportedly',
#   'from',
#   'wearing',
#   'heels',
#   'and',
#   'being',
#   'overweight'],
#  ['north',
#   'korean',
#   'leader',
#   'kim',
#   'jong',
#   'un',
#   'not',
#   'missing',
#   'just',
#   'having',
#   'ankle',
#   'surgery'],
#  ['kim', 'jong', 'un', 'so', 'fat', 'he', 'has', 'fractured', 'his', 'ankles'],
#  ['kim', 'jong', 'un', 'so', 'fat', 'he', 'injured', 'his', 'ankles'],
#  ['four',
#   'theories',
#   'on',
#   'what',
#   'may',
#   'be',
#   'ailing',
#   'kim',
#   'jong',
#   'un'],
#  ['kim', 'jong', 'un', 'obese', 'leader', 'fractured', 'both', 'ankles'],
#  ['north',
#   'korean',
#   'leader',
#   'kim',
#   'jong',
#   'un',
#   'had',
#   'ankle',
#   'surgery',
#   'report',
#   'says'],
#  ['kim',
#   'jong',
#   'un',
#   'may',
#   'be',
#   'dying',
#   'because',
#   'he',
#   's',
#   'addicted',
#   'to',
#   'swiss',
#   'cheese'],
#  ['cheese',
#   'blamed',
#   'for',
#   'north',
#   'korean',
#   'leader',
#   'kim',
#   'jong',
#   'un',
#   's',
#   'broken',
#   'ankles'],
#  ['cheese', 'addiction', 'breaks', 'kim', 'jong', 'un', 's', 'ankles'],
#  ['is',
#   'kim',
#   'jong',
#   'ill',
#   'north',
#   'korean',
#   'dictator',
#   'in',
#   'poor',
#   'health',
#   'as',
#   'his',
#   'weight',
#   'has',
#   'ballooned',
#   'thanks',
#   'to',
#   'an',
#   'obsession',
#   'with',
#   'cheese'],
#  ['kim',
#   'jong',
#   'is',
#   'un',
#   'well',
#   'and',
#   'it',
#   'could',
#   'be',
#   'gout',
#   'north',
#   'korea',
#   'confirms',
#   'its',
#   'young',
#   'dictator',
#   'is',
#   'suffering',
#   'discomfort',
#   'after',
#   'addiction',
#   'to',
#   'swiss',
#   'cheese',
#   'revealed'],
#  ['fat',
#   'dictator',
#   'kim',
#   'jong',
#   'un',
#   'dying',
#   'from',
#   'cheese',
#   'addiction'],
#  ['missing',
#   'kim',
#   'jong',
#   'un',
#   'suffering',
#   'with',
#   'condition',
#   'after',
#   'cheese',
#   'binge'],
#  ['switzerland',
#   's',
#   'assassination',
#   'kim',
#   'jong',
#   'un',
#   'might',
#   'die',
#   'from',
#   'cheese',
#   'overdose'],
#  ['kim', 'jong', 'un', 's', 'discomfort', 'down', 'to', 'cheese', 'addiction'],
#  ['kim',
#   'jong',
#   'un',
#   'loves',
#   'cheese',
#   'so',
#   'much',
#   'he',
#   's',
#   'ballooned',
#   'in',
#   'size',
#   'and',
#   'walks',
#   'with',
#   'limp'],
#  ['north',
#   'korean',
#   'dictator',
#   'kim',
#   'jong',
#   'un',
#   'may',
#   'be',
#   'seriously',
#   'ill',
#   'from',
#   'eating',
#   'too',
#   'much',
#   'emmental',
#   'cheese',
#   'report'],
#  ['kim',
#   'jong',
#   'un',
#   'relying',
#   'on',
#   'cobra',
#   'wine',
#   'after',
#   'problems',
#   'with',
#   'trouser',
#   'snake'],
#  ['kim',
#   'jong',
#   'un',
#   'drinks',
#   'rare',
#   'snake',
#   'wine',
#   'to',
#   'boost',
#   'love',
#   'life'],
#  ['kim',
#   'jong',
#   'un',
#   'necks',
#   'litres',
#   'of',
#   'rare',
#   'snake',
#   'wine',
#   'because',
#   'he',
#   's',
#   'too',
#   'fat',
#   'to',
#   'please',
#   'his',
#   'wife'],
#  ['snake',
#   'wine',
#   'to',
#   'the',
#   'rescue',
#   'of',
#   'kim',
#   'jong',
#   'un',
#   's',
#   'love',
#   'life'],
#  ['kim', 'jong', 'un', 'necks', 'snake', 'wine', 'for', 'virility'],
#  ['jose',
#   'canseco',
#   'accidentally',
#   'shoots',
#   'self',
#   'in',
#   'the',
#   'hand',
#   'at',
#   'vegas',
#   'home'],
#  ['reportjose',
#   'canseco',
#   'accidentally',
#   'shot',
#   'at',
#   'his',
#   'home',
#   'tonight'],
#  ['jose', 'canseco', 'shoots', 'self', 'in', 'hand'],
#  ['jose', 'canseco', 'accidentally', 'shot'],
#  ['jose',
#   'canseco',
#   'accidentally',
#   'shot',
#   'himself',
#   'in',
#   'the',
#   'hand',
#   'update',
#   'shot',
#   'off',
#   'middle',
#   'finger'],
#  ['baseball',
#   'star',
#   'jose',
#   'canseco',
#   'hurt',
#   'in',
#   'accidental',
#   'shooting'],
#  ['former',
#   'baseball',
#   'star',
#   'jose',
#   'canseco',
#   'accidentally',
#   'shot',
#   'himself',
#   'in',
#   'the',
#   'hand'],
#  ['jose', 'canseco', 'accidentally', 'shot'],
#  ['jose',
#   'canseco',
#   'injured',
#   'in',
#   'accidental',
#   'shooting',
#   'per',
#   'reports'],
#  ['breaking',
#   'brat',
#   'pack',
#   'judd',
#   'nelson',
#   'found',
#   'dead',
#   'in',
#   'los',
#   'angeles',
#   'condo'],
#  ['don',
#   't',
#   'worry',
#   'the',
#   'breakfast',
#   'club',
#   'star',
#   'judd',
#   'nelson',
#   'is',
#   'not',
#   'dead'],
#  ['judd',
#   'nelson',
#   'rebuffs',
#   'internet',
#   'rumors',
#   'that',
#   'he',
#   'died',
#   'of',
#   'a',
#   'drug',
#   'overdose'],
#  ['80s',
#   'brat',
#   'pack',
#   'star',
#   'judd',
#   'nelson',
#   'forced',
#   'to',
#   'deny',
#   'that',
#   'he',
#   's',
#   'dead',
#   'after',
#   'fake',
#   'news',
#   'story',
#   'starts',
#   'trending',
#   'on',
#   'social',
#   'media'],
#  ['judd',
#   'nelson',
#   'proof',
#   'of',
#   'life',
#   'after',
#   'death',
#   'hoax',
#   'fox',
#   'news',
#   'impersonator',
#   'claims',
#   'actor',
#   'found',
#   'dead',
#   'in',
#   'los',
#   'angeles',
#   'condo',
#   'updated'],
#  ['judd', 'nelson', 'isn', 't', 'dead', 'report', 'is', 'a', 'hoax'],
#  ['fake',
#   'fox',
#   'news',
#   'website',
#   'reports',
#   'judd',
#   'nelson',
#   's',
#   'death',
#   'for',
#   'some',
#   'reason'],
#  ['kanye', 'west', 'barred', 'from', 'all', 'future', 'awards', 'shows'],
#  ['kanye', 'banned'],
#  ['have',
#   'kanye',
#   'kim',
#   'been',
#   'banned',
#   'from',
#   'future',
#   'grammy',
#   'ceremonies'],
#  ['fowler',
#   'falls',
#   'for',
#   'fake',
#   'website',
#   'makes',
#   'crazy',
#   'claims',
#   'about',
#   'tennis',
#   'star'],
#  ['kei',
#   'nishikori',
#   'highest',
#   'paid',
#   'tennis',
#   'player',
#   'in',
#   'the',
#   'world'],
#  ['satire',
#   'website',
#   'fools',
#   'espn',
#   'kei',
#   'nishikori',
#   'isn',
#   't',
#   'highest',
#   'paid',
#   'tennis',
#   'star'],
#  ...]

# %%
len(headlines_tok[0])
# Out:
# 16

# %%
claims_tok_stemmed = []
for claim in claims_tok:
    claim_tok_stemmed = []
    for tok in claim:
        claim_tok_stemmed.append(stemmer.stem(tok))
    claims_tok_stemmed.append(claim_tok_stemmed)

# %%
headlines_tok_stemmed = []
for headline in headlines_tok:
    headline_tok_stemmed = []
    for tok in headline:
        headline_tok_stemmed.append(stemmer.stem(tok))
    headlines_tok_stemmed.append(headline_tok_stemmed)

# %%
pairs_tok = [list(itertools.product(claim_tok, headline_tok)) for claim_tok, headline_tok in zip(claims_tok, headlines_tok)]

# %%
pairs_tok_stemmed = [list(itertools.product(claim_tok_stemmed, headline_tok_stemmed)) for claim_tok_stemmed, headline_tok_stemmed in zip(claims_tok_stemmed, headlines_tok_stemmed)]

# %%
pairs_tok[1]
# Out:
# [('apple', 'ubs'),
#  ('apple', 'survey'),
#  ('apple', 'finds'),
#  ('apple', '10'),
#  ('apple', 'of'),
#  ('apple', 'consumers'),
#  ('apple', 'want'),
#  ('apple', 'a'),
#  ('apple', 'smartwatch'),
#  ('apple', 'expects'),
#  ('apple', '24m'),
#  ('apple', 'apple'),
#  ('apple', 'watch'),
#  ('apple', 'sales'),
#  ('apple', 'in'),
#  ('apple', 'fiscal'),
#  ('apple', '2015'),
#  ('will', 'ubs'),
#  ('will', 'survey'),
#  ('will', 'finds'),
#  ('will', '10'),
#  ('will', 'of'),
#  ('will', 'consumers'),
#  ('will', 'want'),
#  ('will', 'a'),
#  ('will', 'smartwatch'),
#  ('will', 'expects'),
#  ('will', '24m'),
#  ('will', 'apple'),
#  ('will', 'watch'),
#  ('will', 'sales'),
#  ('will', 'in'),
#  ('will', 'fiscal'),
#  ('will', '2015'),
#  ('sell', 'ubs'),
#  ('sell', 'survey'),
#  ('sell', 'finds'),
#  ('sell', '10'),
#  ('sell', 'of'),
#  ('sell', 'consumers'),
#  ('sell', 'want'),
#  ('sell', 'a'),
#  ('sell', 'smartwatch'),
#  ('sell', 'expects'),
#  ('sell', '24m'),
#  ('sell', 'apple'),
#  ('sell', 'watch'),
#  ('sell', 'sales'),
#  ('sell', 'in'),
#  ('sell', 'fiscal'),
#  ('sell', '2015'),
#  ('24', 'ubs'),
#  ('24', 'survey'),
#  ('24', 'finds'),
#  ('24', '10'),
#  ('24', 'of'),
#  ('24', 'consumers'),
#  ('24', 'want'),
#  ('24', 'a'),
#  ('24', 'smartwatch'),
#  ('24', 'expects'),
#  ('24', '24m'),
#  ('24', 'apple'),
#  ('24', 'watch'),
#  ('24', 'sales'),
#  ('24', 'in'),
#  ('24', 'fiscal'),
#  ('24', '2015'),
#  ('million', 'ubs'),
#  ('million', 'survey'),
#  ('million', 'finds'),
#  ('million', '10'),
#  ('million', 'of'),
#  ('million', 'consumers'),
#  ('million', 'want'),
#  ('million', 'a'),
#  ('million', 'smartwatch'),
#  ('million', 'expects'),
#  ('million', '24m'),
#  ('million', 'apple'),
#  ('million', 'watch'),
#  ('million', 'sales'),
#  ('million', 'in'),
#  ('million', 'fiscal'),
#  ('million', '2015'),
#  ('apple', 'ubs'),
#  ('apple', 'survey'),
#  ('apple', 'finds'),
#  ('apple', '10'),
#  ('apple', 'of'),
#  ('apple', 'consumers'),
#  ('apple', 'want'),
#  ('apple', 'a'),
#  ('apple', 'smartwatch'),
#  ('apple', 'expects'),
#  ('apple', '24m'),
#  ('apple', 'apple'),
#  ('apple', 'watch'),
#  ('apple', 'sales'),
#  ('apple', 'in'),
#  ('apple', 'fiscal'),
#  ('apple', '2015'),
#  ('watches', 'ubs'),
#  ('watches', 'survey'),
#  ('watches', 'finds'),
#  ('watches', '10'),
#  ('watches', 'of'),
#  ('watches', 'consumers'),
#  ('watches', 'want'),
#  ('watches', 'a'),
#  ('watches', 'smartwatch'),
#  ('watches', 'expects'),
#  ('watches', '24m'),
#  ('watches', 'apple'),
#  ('watches', 'watch'),
#  ('watches', 'sales'),
#  ('watches', 'in'),
#  ('watches', 'fiscal'),
#  ('watches', '2015'),
#  ('in', 'ubs'),
#  ('in', 'survey'),
#  ('in', 'finds'),
#  ('in', '10'),
#  ('in', 'of'),
#  ('in', 'consumers'),
#  ('in', 'want'),
#  ('in', 'a'),
#  ('in', 'smartwatch'),
#  ('in', 'expects'),
#  ('in', '24m'),
#  ('in', 'apple'),
#  ('in', 'watch'),
#  ('in', 'sales'),
#  ('in', 'in'),
#  ('in', 'fiscal'),
#  ('in', '2015'),
#  ('the', 'ubs'),
#  ('the', 'survey'),
#  ('the', 'finds'),
#  ('the', '10'),
#  ('the', 'of'),
#  ('the', 'consumers'),
#  ('the', 'want'),
#  ('the', 'a'),
#  ('the', 'smartwatch'),
#  ('the', 'expects'),
#  ('the', '24m'),
#  ('the', 'apple'),
#  ('the', 'watch'),
#  ('the', 'sales'),
#  ('the', 'in'),
#  ('the', 'fiscal'),
#  ('the', '2015'),
#  ('first', 'ubs'),
#  ('first', 'survey'),
#  ('first', 'finds'),
#  ('first', '10'),
#  ('first', 'of'),
#  ('first', 'consumers'),
#  ('first', 'want'),
#  ('first', 'a'),
#  ('first', 'smartwatch'),
#  ('first', 'expects'),
#  ('first', '24m'),
#  ('first', 'apple'),
#  ('first', 'watch'),
#  ('first', 'sales'),
#  ('first', 'in'),
#  ('first', 'fiscal'),
#  ('first', '2015'),
#  ('nine', 'ubs'),
#  ('nine', 'survey'),
#  ('nine', 'finds'),
#  ('nine', '10'),
#  ('nine', 'of'),
#  ('nine', 'consumers'),
#  ('nine', 'want'),
#  ('nine', 'a'),
#  ('nine', 'smartwatch'),
#  ('nine', 'expects'),
#  ('nine', '24m'),
#  ('nine', 'apple'),
#  ('nine', 'watch'),
#  ('nine', 'sales'),
#  ('nine', 'in'),
#  ('nine', 'fiscal'),
#  ('nine', '2015'),
#  ('months', 'ubs'),
#  ('months', 'survey'),
#  ('months', 'finds'),
#  ('months', '10'),
#  ('months', 'of'),
#  ('months', 'consumers'),
#  ('months', 'want'),
#  ('months', 'a'),
#  ('months', 'smartwatch'),
#  ('months', 'expects'),
#  ('months', '24m'),
#  ('months', 'apple'),
#  ('months', 'watch'),
#  ('months', 'sales'),
#  ('months', 'in'),
#  ('months', 'fiscal'),
#  ('months', '2015')]

# %%
with open("../data/ppdb-2.0-xl-lexical.pkl", "rb") as f:
    ppdb_dict = pickle.load(f)

# %%
def ppdb_func(stem_pair, token_pair, ppdb_dict, max_score=10, min_score=-10):
    paraphrase = ppdb_dict.get(token_pair[0], False)
    if stem_pair[0] == stem_pair[1]:
        return max_score
    elif paraphrase and token_pair[1] in paraphrase:
        ppdb_score = paraphrase[token_pair[1]][0]
        return ppdb_score
    else:
        return min_score

# %%
N = len(pairs_tok)
max_score = 10
min_score = -10
alignment_feature = []
for i in range(N):
    sample_tok = pairs_tok[i]
    sample_stem = pairs_tok_stemmed[i]
    M = len(sample_tok)
    score_matrix = []
    current_word = ""
#     input(len(headlines_tok[i]))
    for j in range(M):
        stem_pair = sample_stem[j]
        token_pair = sample_tok[j]
#         input(token_pair)
#         input(j%len(headlines_tok[i]))
        if j%len(headlines_tok[i]) == 0:
#             input("next word")
            current_word = token_pair[0]
            score_matrix.append([])
        score_matrix[-1].append(-ppdb_func(stem_pair, token_pair, ppdb_dict))
#         print(score_matrix)
    try:
        row_ind, col_ind = linear_sum_assignment(score_matrix)
    except:
        input([len(s) for s in score_matrix])
        input(pairs_tok[i])
    alignment_feature.append(-np.array(score_matrix)[row_ind, col_ind].sum())

# %%
alignment_feature
# Out:
# [10.0,
#  -46.80946,
#  -60,
#  79.87683,
#  2.7050899999999984,
#  -7.051629999999999,
#  -3.959340000000001,
#  72.86744999999999,
#  -4.054539999999999,
#  15.618910000000003,
#  12.94837,
#  -14.34654,
#  42.2954,
#  29.09169,
#  110.0,
#  66.3125,
#  115.81581999999999,
#  92.86744999999999,
#  72.86744999999999,
#  38.52091,
#  -27.051630000000003,
#  12.94837,
#  63.22195,
#  56.31424,
#  -26.381730000000005,
#  -13.09683,
#  -26.381730000000005,
#  -20.0,
#  -40.0,
#  -26.381730000000005,
#  39.912119999999994,
#  -20.0,
#  -26.381730000000005,
#  -40.0,
#  0.15867000000000075,
#  -20,
#  -20,
#  50,
#  -0.0,
#  20,
#  2.9874599999999987,
#  30,
#  -40,
#  30.0,
#  40,
#  -10,
#  -10,
#  -10,
#  10,
#  30,
#  10,
#  -10,
#  10,
#  10,
#  -10,
#  -30.0,
#  3.17938,
#  10,
#  30,
#  50,
#  50,
#  23.00141,
#  10,
#  -17.29043,
#  -30,
#  -30,
#  30,
#  -30.0,
#  -10,
#  33.2281,
#  20,
#  20,
#  0,
#  40.0,
#  20,
#  20,
#  13.17185,
#  13.2701,
#  0,
#  12.898579999999999,
#  13.24986,
#  13.53668,
#  33.17798,
#  -40,
#  -10,
#  50,
#  30,
#  2.863109999999999,
#  13.15925,
#  -60,
#  -46.72255,
#  -10,
#  -10,
#  -40,
#  -10,
#  -20,
#  10,
#  3.39708,
#  -10,
#  20,
#  -40,
#  13.66261,
#  30,
#  -56.191590000000005,
#  -6.337389999999999,
#  -40,
#  -40,
#  -40,
#  13.66261,
#  -40,
#  10,
#  -20,
#  10,
#  -40,
#  -40,
#  10,
#  3.4719800000000003,
#  -30,
#  23.37845,
#  -40,
#  -26.586600000000004,
#  33.54127,
#  -7.015999999999998,
#  20,
#  -37.016,
#  -30.0,
#  -36.587360000000004,
#  20,
#  -20,
#  20,
#  40,
#  0,
#  0,
#  50.0,
#  23.103450000000002,
#  23.03037,
#  0,
#  13.02307,
#  -10,
#  -70,
#  53.57798,
#  23.23303,
#  -6.55166,
#  -36.55166,
#  -20.0,
#  10,
#  20,
#  -6.911079999999998,
#  20,
#  13.008009999999999,
#  13.08892,
#  0,
#  3.0080100000000005,
#  33.10655,
#  10,
#  120.0,
#  40,
#  30,
#  20,
#  -6.725380000000001,
#  50,
#  13.072879999999998,
#  50,
#  6.780889999999999,
#  23.105330000000002,
#  40,
#  70,
#  10.0,
#  30,
#  30,
#  30,
#  10,
#  10,
#  30,
#  36.02231999999999,
#  30,
#  10,
#  10,
#  10,
#  -30,
#  -70.94353,
#  -19.986089999999997,
#  -53.80189,
#  -66.51961,
#  -66.55758,
#  -16.952640000000002,
#  -30.751810000000003,
#  -17.34067,
#  15.91504,
#  70.0,
#  -10,
#  3.500679999999999,
#  120.0,
#  96.7678,
#  9.494160000000003,
#  62.99392,
#  36.24226,
#  -23.974739999999997,
#  76.7678,
#  6.04561,
#  36.51737,
#  -3.228049999999998,
#  -46.82124,
#  -6.9086099999999995,
#  29.660940000000004,
#  86.7678,
#  76.7678,
#  -0.0,
#  8.49595,
#  42.90464,
#  -33.79511,
#  49.660940000000004,
#  66.7678,
#  -20.064,
#  62.89314,
#  49.49743,
#  22.84086,
#  -36.98331,
#  52.99392,
#  10,
#  -23.70603,
#  3.0621299999999962,
#  -10,
#  -30,
#  3.1532200000000046,
#  23.39708,
#  -20.0,
#  13.36219,
#  -6.69003,
#  30,
#  -0.0,
#  -20.0,
#  6.290330000000002,
#  -20,
#  -6.637810000000002,
#  -20,
#  13.36294,
#  -20.0,
#  -7.051629999999999,
#  33.446259999999995,
#  20,
#  40,
#  -50,
#  -20,
#  -20,
#  52.6776,
#  -20,
#  -50,
#  -20,
#  60,
#  40,
#  40,
#  -20,
#  -40,
#  -40,
#  40,
#  -20,
#  -13.91206,
#  13.13433,
#  0,
#  13.246780000000001,
#  0,
#  40,
#  20.0,
#  0,
#  33.13433,
#  12.93638,
#  20.0,
#  0,
#  32.94837,
#  -6.60138,
#  0,
#  33.36294,
#  13.246780000000001,
#  0,
#  13.36294,
#  20.0,
#  0,
#  13.30997,
#  13.246780000000001,
#  -30.0,
#  -63.71494,
#  -33.614540000000005,
#  30.0,
#  16.42282,
#  13.22566,
#  45.9183,
#  3.36454,
#  52.94837,
#  70,
#  30,
#  50.0,
#  32.94837,
#  65.805,
#  62.92058,
#  26.14722,
#  90.0,
#  30.0,
#  0,
#  60,
#  20.0,
#  30,
#  50,
#  -7.051629999999999,
#  70,
#  -10,
#  20,
#  30,
#  23.330259999999996,
#  23.330259999999996,
#  23.330259999999996,
#  33.330259999999996,
#  42.984,
#  62.96482,
#  43.330259999999996,
#  90,
#  23.330259999999996,
#  23.330259999999996,
#  42.984,
#  43.330259999999996,
#  42.96482,
#  9.397549999999999,
#  -43.66344,
#  -4.065019999999999,
#  -30.74718,
#  -30,
#  -10,
#  30,
#  -30,
#  50.0,
#  90,
#  10,
#  10,
#  50,
#  -27.31458,
#  -10.0,
#  30.0,
#  -13.72908,
#  53.07722,
#  40.0,
#  25.999830000000003,
#  -44.153310000000005,
#  40.0,
#  26.08513,
#  26.61334,
#  45.59803,
#  46.31608,
#  20,
#  26.08513,
#  46.06648,
#  25.848010000000002,
#  29.4035,
#  70,
#  60,
#  60,
#  40.0,
#  60.0,
#  60,
#  60,
#  23.028799999999997,
#  -10.0,
#  13.03827,
#  -14.192529999999998,
#  10,
#  2.81832,
#  120,
#  -24.13534,
#  50,
#  -20.94744,
#  -53.9496,
#  70,
#  -77.18895,
#  -13.768369999999997,
#  3.1240799999999993,
#  -37.07649,
#  40,
#  36.137460000000004,
#  -40.0,
#  -23.11824,
#  0,
#  -40,
#  30,
#  -10,
#  -10,
#  -16.52363,
#  20,
#  0,
#  -10,
#  -40,
#  13.378880000000002,
#  -26.25331,
#  -26.69453,
#  -80,
#  -50,
#  -80,
#  -70,
#  -6.253309999999999,
#  -46.403800000000004,
#  -40,
#  -66.59199,
#  -66.4038,
#  -50,
#  -56.403800000000004,
#  -10,
#  -0.0,
#  0,
#  2.87724,
#  -10.66975,
#  -50.46431,
#  -43.722229999999996,
#  61.61524,
#  -50.46431,
#  46.22441,
#  -7.03454,
#  10,
#  -10,
#  -26.637059999999998,
#  -0.0,
#  -26.94818,
#  -46.68161,
#  40.0,
#  -40.0,
#  -20.0,
#  -50,
#  -40.0,
#  -40.0,
#  -0.0,
#  53.28568,
#  -20.0,
#  -86.67608,
#  -0.0,
#  0,
#  13.016800000000003,
#  23.0168,
#  56.67564,
#  63.542249999999996,
#  96.72937999999999,
#  70.11776,
#  -30.30722,
#  6.30256,
#  90.0,
#  -23.46279,
#  17.250569999999996,
#  103.12227,
#  66.2389,
#  10,
#  30,
#  30,
#  10,
#  0,
#  -46.862719999999996,
#  -63.558080000000004,
#  -17.339840000000002,
#  16.391089999999995,
#  110.0,
#  -26.637059999999998,
#  -3.5012899999999973,
#  -36.63706,
#  -10,
#  113.36294000000001,
#  20,
#  -27.2734,
#  -0.0,
#  -17.039740000000002,
#  2.960259999999998,
#  -24.31314,
#  -14.391559999999998,
#  -41.66496,
#  15.903479999999998,
#  -40,
#  -50,
#  6.6124600000000004,
#  -36.79506,
#  -46.85609,
#  -10,
#  -20,
#  -27.05163,
#  -46.58619,
#  0,
#  12.94837,
#  -10.56173,
#  -50,
#  -3.9933300000000003,
#  0,
#  25.94051,
#  25.70689,
#  32.91308,
#  5.92389,
#  12.79381,
#  12.91308,
#  13.33618,
#  25.82678,
#  26.88833,
#  0,
#  25.70689,
#  -20,
#  0,
#  20,
#  20,
#  40,
#  0,
#  0,
#  -20,
#  20,
#  40.0,
#  -60,
#  53.36045,
#  -0.3907899999999991,
#  -3.6850299999999976,
#  -10,
#  -23.598029999999998,
#  15.861360000000001,
#  23.25694,
#  -47.2194,
#  0,
#  30,
#  0,
#  10,
#  -20,
#  -10,
#  -10,
#  -30,
#  10,
#  13.45608,
#  -30,
#  -24.45169,
#  90.0,
#  -4.209620000000001,
#  -37.239959999999996,
#  16.272919999999996,
#  60.0,
#  22.70351,
#  63.25323,
#  2.9994000000000014,
#  8.425440000000002,
#  23.39688,
#  3.17436,
#  70.0,
#  42.87536,
#  -30.6354,
#  -37.11726,
#  15.790379999999999,
#  8.67312,
#  23.358540000000005,
#  53.1547,
#  -20,
#  -10.0,
#  20.0,
#  -7.231369999999998,
#  -27.12611,
#  40.0,
#  -40.0,
#  13.413159999999998,
#  -33.67299,
#  -20.0,
#  6.906649999999997,
#  -16.98303,
#  65.77095,
#  19.23259,
#  -20,
#  25.847429999999996,
#  3.4131599999999978,
#  -37.07501,
#  -7.07501,
#  -54.4653,
#  -22.91202,
#  -13.661850000000001,
#  -6.98254,
#  5.908940000000001,
#  -50,
#  -37.10852,
#  13.110430000000001,
#  0,
#  0,
#  -60.0,
#  -67.348,
#  53.01746,
#  0,
#  -47.10852,
#  -14.33054,
#  13.01746,
#  -10,
#  -40,
#  50,
#  23.66261,
#  50,
#  -6.99859,
#  10,
#  40,
#  0,
#  0,
#  20.0,
#  80.0,
#  -13.9794,
#  0,
#  2.643950000000004,
#  -90.0,
#  -90.0,
#  -63.64799,
#  -23.856429999999996,
#  -10.0,
#  84.05396,
#  -6.908609999999996,
#  -5.946039999999996,
#  20.0,
#  13.103450000000002,
#  6.596420000000002,
#  63.27439,
#  -76.70060000000001,
#  86.65101999999999,
#  73.27439,
#  63.27439,
#  30,
#  -30,
#  40,
#  -4.1529799999999994,
#  0,
#  50.0,
#  -56.77181,
#  23.542250000000003,
#  -40,
#  -27.03023,
#  -10,
#  -107.03023,
#  -16.891280000000002,
#  -7.0302299999999995,
#  -90,
#  -40.84547,
#  -7.0302299999999995,
#  -24.037709999999997,
#  32.72408,
#  -20,
#  -13.76396,
#  -20.0,
#  -87.04769,
#  -46.69142,
#  -0.9201799999999984,
#  -50,
#  -40.74212,
#  -4.431120000000002,
#  3.343479999999995,
#  -10.34581,
#  102.78433,
#  -10.856970000000004,
#  -73.45703,
#  48.942280000000004,
#  -10.76481,
#  -24.178239999999995,
#  12.942320000000002,
#  28.58462,
#  -6.932169999999999,
#  15.79529,
#  -7.33568,
#  -20.0,
#  -40.0,
#  60.0,
#  -20.0,
#  50.0,
#  25.711840000000002,
#  -13.495320000000001,
#  20.0,
#  35.71184,
#  30.0,
#  3.45716,
#  23.04752,
#  3.45716,
#  20.0,
#  10,
#  22.66432,
#  -46.612539999999996,
#  -66.51185,
#  -30.0,
#  60.0,
#  13.12556,
#  0,
#  12.78032,
#  53.0168,
#  13.0168,
#  -10.0,
#  -0.0,
#  -20.0,
#  -17.44363,
#  -83.69738,
#  12.636690000000002,
#  -23.907799999999998,
#  -23.73901,
#  -116.85616999999999,
#  33.14383,
#  -86.85616999999999,
#  56.02825,
#  -56.85617,
#  66.37876999999999,
#  -73.97175,
#  -6.856169999999999,
#  3.186869999999999,
#  -33.6693,
#  -30,
#  -10,
#  13.12856,
#  13.181399999999996,
#  13.181399999999996,
#  10.0,
#  -16.885930000000002,
#  0,
#  -40,
#  -30,
#  -10,
#  30,
#  -50,
#  -20,
#  10,
#  10,
#  -10,
#  -26.790570000000002,
#  -7.19801,
#  13.20943,
#  43.250280000000004,
#  0,
#  0,
#  13.16819,
#  0,
#  33.47324,
#  -46.850319999999996,
#  -46.793890000000005,
#  -6.83181,
#  10,
#  -10,
#  2.92432,
#  10.0,
#  30,
#  22.93786,
#  40,
#  -30,
#  -37.016,
#  23.45648,
#  10,
#  20.0,
#  52.73071,
#  13.31588,
#  60.0,
#  40.0,
#  40.0,
#  -17.15249,
#  -36.79356,
#  12.948369999999997,
#  -3.2606900000000003,
#  52.84751,
#  12.891480000000001,
#  13.532870000000003,
#  -27.15249,
#  -17.21172,
#  10,
#  -50,
#  10,
#  -10,
#  -50,
#  2.6639899999999983,
#  -30,
#  10,
#  30,
#  30,
#  -10,
#  10,
#  30,
#  2.6639899999999983,
#  2.6639899999999983,
#  3.198550000000001,
#  -23.53277,
#  46.44485,
#  5.74967,
#  23.246299999999998,
#  -4.832709999999998,
#  -30.867739999999998,
#  36.678509999999996,
#  -20.74512,
#  -6.65732,
#  9.925559999999997,
#  9.877059999999998,
#  43.19855,
#  -30.0,
#  -26.66019,
#  -6.768129999999999,
#  14.82416,
#  -7.840420000000002,
#  19.706310000000002,
#  19.706310000000002,
#  12.063289999999999,
#  -3.617359999999998,
#  24.82416,
#  -20.0,
#  -66.37653,
#  -90,
#  -13.906190000000002,
#  -6.385010000000001,
#  81.98452,
#  -27.047690000000003,
#  14.694739999999996,
#  -26.95718,
#  -0.5655500000000018,
#  -3.5190199999999976,
#  2.784880000000001,
#  -53.89137,
#  -33.36553,
#  -4.595189999999999,
#  -24.09932,
#  -26.7299,
#  -50,
#  12.73868,
#  -50,
#  -6.828150000000001,
#  80.0,
#  19.884959999999992,
#  -0.0,
#  -20,
#  -33.45346,
#  -7.261319999999998,
#  26.5153,
#  22.738680000000002,
#  -3.8946200000000006,
#  -10,
#  2.8914800000000014,
#  22.89148,
#  83.58605,
#  0,
#  56.2689,
#  2.652000000000001,
#  2.652000000000001,
#  10.0,
#  20.0,
#  103.16028,
#  103.16028,
#  60.0,
#  -23.733159999999998,
#  -33.720439999999996,
#  -30.3575,
#  20,
#  -60,
#  20,
#  40,
#  40,
#  -20,
#  -20,
#  60,
#  -40,
#  40,
#  -20,
#  40,
#  -20,
#  40,
#  40,
#  40,
#  -40,
#  40,
#  60,
#  40,
#  40,
#  -20,
#  0,
#  0,
#  0,
#  60,
#  -60,
#  0,
#  20,
#  -20,
#  -60,
#  20,
#  60,
#  53.257310000000004,
#  40.0,
#  -20,
#  60,
#  -26.826140000000002,
#  -40,
#  0,
#  60,
#  -20,
#  20,
#  60,
#  20,
#  13.17386,
#  -20,
#  -40,
#  -6.74269,
#  0,
#  -46.90053,
#  -17.28415,
#  -30.6115,
#  -40.16977,
#  -53.72128000000001,
#  -47.65444,
#  -73.64545,
#  10.0,
#  3.2253299999999996,
#  30.0,
#  -16.77467,
#  -30.0,
#  -10,
#  0,
#  53.06619,
#  -3.9331899999999997,
#  60.0,
#  93.06884,
#  46.05019,
#  33.06619,
#  19.417720000000003,
#  46.05019,
#  -13.933189999999996,
#  19.50026,
#  -6.58929,
#  -20.32004,
#  -100,
#  20.0,
#  -40,
#  -40.0,
#  50,
#  10,
#  -40,
#  30,
#  60.0,
#  -10,
#  23.48059,
#  -10,
#  2.9962599999999995,
#  3.4805899999999994,
#  -3.974260000000001,
#  29.34906,
#  -36.47143,
#  2.9962599999999995,
#  -56.90741,
#  -30.884420000000006,
#  -33.38167,
#  9.11558,
#  -23.49427,
#  -10.88442,
#  22.487319999999997,
#  -30.884420000000006,
#  -30.884420000000006,
#  -57.19346,
#  -17.19346,
#  -37.19346,
#  -30.884420000000006,
#  9.11558,
#  13.430489999999999,
#  0,
#  3.1154100000000007,
#  53.16046,
#  20,
#  12.8261,
#  0,
#  13.115409999999997,
#  26.25659,
#  26.59095,
#  0,
#  20,
#  12.8261,
#  0,
#  33.43049,
#  20,
#  -20,
#  33.43049,
#  13.115409999999997,
#  22.984,
#  -17.016,
#  12.984000000000002,
#  2.85675,
#  2.91439,
#  -10,
#  -7.085609999999999,
#  -17.016,
#  2.9840000000000018,
#  36.089290000000005,
#  50,
#  -20,
#  10,
#  12.984000000000002,
#  -7.015999999999998,
#  20,
#  0,
#  -0.0,
#  0,
#  20.0,
#  33.216139999999996,
#  13.25092,
#  26.43569,
#  20.0,
#  26.0945,
#  20,
#  40.0,
#  12.96482,
#  33.00828,
#  20.0,
#  40,
#  26.19372,
#  53.46988,
#  20.0,
#  23.257640000000002,
#  -53.99426,
#  70.0,
#  -0.0,
#  ...]

# %%
# need to still normalize
